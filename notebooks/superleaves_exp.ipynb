# %%
from itertools import combinations
import numpy as np
import pandas as pd
import seaborn as sns
from string import ascii_uppercase
import time as time

# %matplotlib inline

# %% [markdown]
# Create a dictionary of all possible 1 to 6-tile leaves

# %%
tilebag = ['A']*9+['B']*2+['C']*2+['D']*4+['E']*12+\
          ['F']*2+['G']*3+['H']*2+['I']*9+['J']*1+\
          ['K']*1+['L']*4+['M']*2+['N']*6+['O']*8+\
          ['P']*2+['Q']*1+['R']*6+['S']*4+['T']*6+\
          ['U']*4+['V']*2+['W']*2+['X']*1+['Y']*2+\
          ['Z']*1+['?']*2
            
tiles = [x for x in ascii_uppercase] + ['?']
# leaves_2 = sorted(list(set(list(combinations(tilebag,2)))))
# leaves_2 = [x[0]+x[1] for x in leaves_2]

# %%
t0 = time.time()

maximum_superleave_length = 5
leaves = {i:sorted(list(set(list(combinations(tilebag,i))))) for i in 
          range(1,maximum_superleave_length+1)}

for i in range(1,maximum_superleave_length+1):
    leaves[i] = [''.join(leave) for leave in leaves[i]]
    
t1 = time.time()
print('Calculated superleaves up to length {} in {} seconds'.format(
    maximum_superleave_length,t1-t0))
# Out:
# Calculated superleaves up to length 5 in 19.917773008346558 seconds

# %% [markdown]
# The bottom creates the full set of leaves for all lengths from 1-5 (6 breaks on my local machine)

# %%
for i in range(1,6):
    print(i,len(leaves[i]))
# Out:
# 1 27
# 2 373
# 3 3509
# 4 25254
# 5 148150

# %%
column_dict = {
    0:'rack',
    1:'score',
    2:'tiles_remaining'
}
df = pd.read_csv('log_games.csv', header=None, keep_default_na=False)
df.rename(columns=column_dict,inplace=True)

# %%
tile_limit = 7
df = df.loc[df['tiles_remaining']>=tile_limit]

# %% [markdown]
# Alphabetize rack

# %%
df['rack'] = df['rack'].apply(lambda x: ''.join(sorted(x)))

# %% [markdown]
# Create flag of whether each letter is contained in a rack, and also check for multiples

# %%
for multiple in range(1,6):
    t0 = time.time()

    # iterate through all 27 tiles
    for c in leaves[1]:

        if multiple*c in leaves[multiple]:
            df[multiple*c] = df['rack'].apply(lambda x: multiple*c in x)
            
    t1 = time.time()
    print('Added columns for all duplicates up to length {} in {} seconds'.format(multiple,t1-t0))
# Out:
# Added columns for all duplicates up to length 1 in 124.51392412185669 seconds
# Added columns for all duplicates up to length 2 in 119.02785897254944 seconds
# Added columns for all duplicates up to length 3 in 64.65550684928894 seconds
# Added columns for all duplicates up to length 4 in 56.814465045928955 seconds
# Added columns for all duplicates up to length 5 in 36.3196918964386 seconds

# %%
# following variable indicates what length of superleave we try to calculate up to.
# WARNING: might break for now if you try to do too long.
ev_calculator_max_length = 3

# %%
all_leaves = []

for i in range(1,ev_calculator_max_length+1):
    all_leaves += leaves[i]
    
df_dict = {leave: pd.DataFrame() for leave in all_leaves}
df_dict[''] = df

ev_df = pd.DataFrame(columns=['mean','std','count','ev','synergy'],
                     index=all_leaves)

# %% [markdown]
# To find all of the racks corresponding to a particular leave, we have added columns to the dataframe of plays df marking each letter (A, B, C...) and also for duplicates (AA, BB, CC...) and triplicates where possible (AAA, DDD, EEE...).
#
# If the letters in a given leave are all different, we can look for rows by using df['A']&df['B']. However, if there are duplicates involved, we have to look for df['AA']. The following function gives the correct dataframe columns to be looked up.

# %%
def get_columns(leave):
    letters=list(set(leave))
    tags = []
    
    for l in letters:
        tags += [sum([l==letter for letter in leave])*l]
    
    return tags

# %%
for leave_length in range(1,ev_calculator_max_length+1):
    print(leave_length)
    t0 = time.time()
    
    for leave in leaves[leave_length][:20]:
        t2 = time.time()
        condition = df_dict[leave[:-1]][get_columns(leave)].all(axis=1)
        df_dict[leave] = df_dict[leave[:-1]].loc[condition]
        t4 = time.time()
        ev_df.loc[leave]['mean'] = df_dict[leave]['score'].mean()
        t5 = time.time()
        ev_df.loc[leave]['std'] = df_dict[leave]['score'].std()
        t6 = time.time()
        ev_df.loc[leave]['count'] = len(df_dict[leave])
        t3 = time.time()
        print('Calculated EV of leave {} in {} seconds'.format(
              leave,t3-t2))
        # print(t4-t2)
        # print(t5-t4)
        # print(t6-t5)
        # print(t3-t6)
        
    t1 = time.time()
    print('Calculated mean, std and count in {} seconds'.format(t1-t0))
# Out:
# 1
# Calculated EV of leave ? in 0.49558520317077637 seconds
# Calculated EV of leave A in 1.8147618770599365 seconds
# Calculated EV of leave B in 0.7003812789916992 seconds
# Calculated EV of leave C in 0.8366820812225342 seconds
# Calculated EV of leave D in 1.094351053237915 seconds
# Calculated EV of leave E in 2.4343879222869873 seconds
# Calculated EV of leave F in 0.6291160583496094 seconds
# Calculated EV of leave G in 1.065903902053833 seconds
# Calculated EV of leave H in 0.6193957328796387 seconds
# Calculated EV of leave I in 2.3928537368774414 seconds
# Calculated EV of leave J in 0.46109604835510254 seconds
# Calculated EV of leave K in 0.43598270416259766 seconds
# Calculated EV of leave L in 1.3575332164764404 seconds
# Calculated EV of leave M in 0.6677212715148926 seconds
# Calculated EV of leave N in 1.656102180480957 seconds
# Calculated EV of leave O in 1.9810559749603271 seconds
# Calculated EV of leave P in 0.6283071041107178 seconds
# Calculated EV of leave Q in 0.5599801540374756 seconds
# Calculated EV of leave R in 1.7081310749053955 seconds
# Calculated EV of leave S in 1.083954095840454 seconds
# Calculated mean, std and count in 22.625595092773438 seconds
# 2
# Calculated EV of leave ?? in 0.17515015602111816 seconds
# Calculated EV of leave A? in 1.3068351745605469 seconds
# Calculated EV of leave AA in 0.32617902755737305 seconds
# Calculated EV of leave AB in 0.5385229587554932 seconds
# Calculated EV of leave AC in 0.5290439128875732 seconds
# Calculated EV of leave AD in 0.7339761257171631 seconds
# Calculated EV of leave AE in 1.3826828002929688 seconds
# Calculated EV of leave AF in 0.5321347713470459 seconds
# Calculated EV of leave AG in 0.6661920547485352 seconds
# Calculated EV of leave AH in 0.4861769676208496 seconds
# Calculated EV of leave AI in 1.1878149509429932 seconds
# Calculated EV of leave AJ in 0.40920495986938477 seconds
# Calculated EV of leave AK in 0.44895005226135254 seconds
# Calculated EV of leave AL in 0.7374851703643799 seconds
# Calculated EV of leave AM in 0.5090761184692383 seconds
# Calculated EV of leave AN in 0.9530880451202393 seconds
# Calculated EV of leave AO in 1.1189558506011963 seconds
# Calculated EV of leave AP in 0.5302309989929199 seconds
# Calculated EV of leave AQ in 0.465717077255249 seconds
# Calculated EV of leave AR in 0.9386911392211914 seconds
# Calculated mean, std and count in 13.97859525680542 seconds
# 3
# Calculated EV of leave A?? in 0.038472890853881836 seconds
# Calculated EV of leave AA? in 0.06636285781860352 seconds
# Calculated EV of leave AAA in 0.03812289237976074 seconds
# Calculated EV of leave AAB in 0.06273913383483887 seconds
# Calculated EV of leave AAC in 0.06815505027770996 seconds
# Calculated EV of leave AAD in 0.07683992385864258 seconds
# Calculated EV of leave AAE in 0.1428847312927246 seconds
# Calculated EV of leave AAF in 0.062371015548706055 seconds
# Calculated EV of leave AAG in 0.08640003204345703 seconds
# Calculated EV of leave AAH in 0.0611419677734375 seconds
# Calculated EV of leave AAI in 0.15913796424865723 seconds
# Calculated EV of leave AAJ in 0.050354957580566406 seconds
# Calculated EV of leave AAK in 0.06000518798828125 seconds
# Calculated EV of leave AAL in 0.0906219482421875 seconds
# Calculated EV of leave AAM in 0.06196904182434082 seconds
# Calculated EV of leave AAN in 0.12330484390258789 seconds
# Calculated EV of leave AAO in 0.1391439437866211 seconds
# Calculated EV of leave AAP in 0.05983400344848633 seconds
# Calculated EV of leave AAQ in 0.05606222152709961 seconds
# Calculated EV of leave AAR in 0.11321902275085449 seconds
# Calculated mean, std and count in 1.6191630363464355 seconds

# %%
for leave_length in range(1,ev_calculator_max_length+1):
    print(leave_length)
    t0 = time.time()
    
    for leave in leaves[leave_length][:20]:
        t2 = time.time()
        condition = df[get_columns(leave)].all(axis=1)
        t4 = time.time()
        ev_df.loc[leave]['mean'] = df.loc[condition]['score'].mean()
        t5 = time.time()
        ev_df.loc[leave]['std'] = df.loc[condition]['score'].std()
        t6 = time.time()
        ev_df.loc[leave]['count'] = len(df.loc[condition])
        t3 = time.time()
        print('Calculated EV of leave {} in {} seconds'.format(
              leave,t3-t2))
        # print(t4-t2)
        # print(t5-t4)
        # print(t6-t5)
        # print(t3-t6)
        
    t1 = time.time()
    print('Calculated mean, std and count in {} seconds'.format(t1-t0))
# Out:
# 1
# Calculated EV of leave ? in 1.176253080368042 seconds
# Calculated EV of leave A in 4.231508016586304 seconds
# Calculated EV of leave B in 1.5274300575256348 seconds
# Calculated EV of leave C in 1.5289928913116455 seconds
# Calculated EV of leave D in 2.3533878326416016 seconds
# Calculated EV of leave E in 5.428741216659546 seconds
# Calculated EV of leave F in 1.473625898361206 seconds
# Calculated EV of leave G in 2.177222967147827 seconds
# Calculated EV of leave H in 1.331714153289795 seconds
# Calculated EV of leave I in 4.9467267990112305 seconds
# Calculated EV of leave J in 0.9408981800079346 seconds
# Calculated EV of leave K in 0.8464927673339844 seconds
# Calculated EV of leave L in 2.6979668140411377 seconds
# Calculated EV of leave M in 1.4689033031463623 seconds
# Calculated EV of leave N in 3.5230090618133545 seconds
# Calculated EV of leave O in 4.104795932769775 seconds
# Calculated EV of leave P in 1.470768928527832 seconds
# Calculated EV of leave Q in 1.0160701274871826 seconds
# Calculated EV of leave R in 3.434680223464966 seconds
# Calculated EV of leave S in 2.025977849960327 seconds
# Calculated mean, std and count in 47.707587003707886 seconds
# 2
# Calculated EV of leave ?? in 0.18126273155212402 seconds
# Calculated EV of leave A? in 1.427961826324463 seconds
# Calculated EV of leave AA in 0.8808398246765137 seconds
# Calculated EV of leave AB in 1.559164047241211 seconds
# Calculated EV of leave AC in 1.3942337036132812 seconds
# Calculated EV of leave AD in 1.7460510730743408 seconds
# Calculated EV of leave AE in 2.948578119277954 seconds
# Calculated EV of leave AF in 1.3345069885253906 seconds
# Calculated EV of leave AG in 1.652536153793335 seconds
# Calculated EV of leave AH in 1.472977876663208 seconds
# Calculated EV of leave AI in 2.887660026550293 seconds
# Calculated EV of leave AJ in 1.154461145401001 seconds
# Calculated EV of leave AK in 1.2348790168762207 seconds
# Calculated EV of leave AL in 1.9324979782104492 seconds
# Calculated EV of leave AM in 1.394611120223999 seconds
# Calculated EV of leave AN in 2.3735849857330322 seconds
# Calculated EV of leave AO in 2.780816078186035 seconds
# Calculated EV of leave AP in 1.3986518383026123 seconds
# Calculated EV of leave AQ in 1.2475650310516357 seconds
# Calculated EV of leave AR in 2.310206890106201 seconds
# Calculated mean, std and count in 33.31563997268677 seconds
# 3
# Calculated EV of leave A?? in 0.7538909912109375 seconds
# Calculated EV of leave AA? in 0.795698881149292 seconds
# Calculated EV of leave AAA in 0.3720707893371582 seconds
# Calculated EV of leave AAB in 0.916323184967041 seconds
# Calculated EV of leave AAC in 0.9638669490814209 seconds
# Calculated EV of leave AAD in 1.1201341152191162 seconds
# Calculated EV of leave AAE in 1.2709031105041504 seconds
# Calculated EV of leave AAF in 0.8571820259094238 seconds
# Calculated EV of leave AAG in 0.9769220352172852 seconds
# Calculated EV of leave AAH in 0.8700330257415771 seconds
# Calculated EV of leave AAI in 1.313148021697998 seconds
# Calculated EV of leave AAJ in 0.7962300777435303 seconds
# Calculated EV of leave AAK in 0.7848477363586426 seconds
# Calculated EV of leave AAL in 1.1041679382324219 seconds
# Calculated EV of leave AAM in 0.8521528244018555 seconds
# Calculated EV of leave AAN in 1.1877381801605225 seconds
# Calculated EV of leave AAO in 1.2338650226593018 seconds
# Calculated EV of leave AAP in 0.8575758934020996 seconds
# Calculated EV of leave AAQ in 0.7755560874938965 seconds
# Calculated EV of leave AAR in 1.1561200618743896 seconds
# Calculated mean, std and count in 18.960906982421875 seconds

# %%
ev_df['pct'] = 100*ev_df['count']/len(df)
ev_df['ev'] = ev_df['mean']-df['score'].mean()

# %% [markdown]
# Calculate leave "synergy", in other words the difference between the EV of the rack and what we'd expect just from adding the individual values of the tiles

# %%
for leave_length in range(2,ev_calculator_max_length+1):
    for leave in leaves[leave_length]:
        ev_df.loc[leave]['synergy'] = ev_df.loc[leave]['ev']-\
                                      sum([ev_df.loc[c]['ev'] for c in leave])

# %%
ev_df
# Out:
#         mean      std     count         ev   synergy         pct
# ?    54.9192  25.1511   1707622    19.4086       NaN     9.24729
# A    36.8361  18.8678   8316804    1.32554       NaN      45.038
# B    35.1204  16.7445   2355819  -0.390212       NaN     12.7575
# C    36.3152  18.7269   2399229   0.804599       NaN     12.9925
# D    36.6047  18.7607   4293197    1.09413       NaN      23.249
# E    37.4298   19.654  10163946    1.91925       NaN     55.0408
# F    35.5469  15.4998   2155441  0.0363451       NaN     11.6724
# G    34.4616  17.4353   4033589   -1.04899       NaN     21.8431
# H    37.9477  16.7506   1952294    2.43714       NaN     10.5723
# I    35.5348  18.8481   9795770  0.0242382       NaN      53.047
# J    36.2047  12.7758   1089626   0.694169       NaN     5.90065
# K    36.7739  15.1085   1027335     1.2633       NaN     5.56333
# L    35.4133  19.0373   5099563  -0.097262       NaN     27.6157
# M    36.9933    17.83   2144535    1.48277       NaN     11.6133
# N    36.0909  19.4518   7009034   0.580319       NaN      37.956
# O    35.2041  17.9802   8337358  -0.306498       NaN     45.1493
# P    36.2213  17.5097   2220310   0.710763       NaN     12.0236
# Q    34.0855  13.9599   1565650   -1.42506       NaN     8.47847
# R    36.4585  19.8752   6791618   0.947892       NaN     36.7787
# S    41.8347  21.2131   3565481    6.32417       NaN     19.3082
# T    35.9993  19.3329   6969576   0.488718       NaN     37.7424
# U    33.1842  16.8019   6242860   -2.32632       NaN      33.807
# V    33.0818  15.3768   2955186    -2.4288       NaN     16.0032
# W     34.296  14.4731   2236099   -1.21461       NaN     12.1091
# X    40.7264   14.171    952087    5.21584       NaN     5.15584
# Y     36.732  15.0429   1952851    1.22148       NaN     10.5753
# Z    42.3702  15.8633    938779    6.85962       NaN     5.08377
# ??   74.4928  23.4158     36874    38.9822  0.164993    0.199684
# A?   57.6156  25.2614    700846    22.1051    1.3709     3.79529
# AA   32.7734   16.346   2018323   -2.73719  -5.38827     10.9298
# ..       ...      ...       ...        ...       ...         ...
# VWZ  36.7945  11.9731     12039    1.28393  -1.93227   0.0651948
# VX?   46.803  14.6793      9116    11.2924  -10.9032   0.0493659
# VXY  39.2562  11.4062     10605    3.74563 -0.262876   0.0574293
# VXZ  40.0928  12.7228      5160    4.58226  -5.06439    0.027943
# VY?  46.4205  19.2657     19041    10.9099  -7.29135    0.103113
# VYY   30.775  9.01273      6106   -4.73559  -4.74974   0.0330658
# VYZ  39.8985  11.9567     10331    4.38789   -1.2644   0.0559455
