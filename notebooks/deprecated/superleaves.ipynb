# %% [markdown]
# #### How to use
# * maximum_superleave_length indicates the maximum length of superleaves to consider. Right now, maximum runnable on my local machine is 5.
# * ev_calculator_max_length indicates the maximum length of superleave that we want to calculate the EV for based on a log file of games (log_file).
#
# #### To-do
# 1. Have creation of duplicates go in reverse so that all necessary columns are present.
#
#
# #### Changelog
# * 1/27/19 - Determined that the speed of creation of the rack dataframes is a function of the length of the dataframe. From that, realized that we should organize leaves by least-frequent to most-frequent letter, such that sub-dataframes are created from the shortest racks possible.

# %%
from itertools import combinations
import numpy as np
import pandas as pd
import seaborn as sns
from string import ascii_uppercase
import time as time

# %matplotlib inline

maximum_superleave_length = 5
ev_calculator_max_length = 5

log_file = 'log_games.csv'

# %% [markdown]
# Create a dictionary of all possible 1 to 6-tile leaves. Also, add functionality for sorting by an arbitrary key - allowing us to put rarest letters first

# %%
tilebag = ['A']*9+['B']*2+['C']*2+['D']*4+['E']*12+\
          ['F']*2+['G']*3+['H']*2+['I']*9+['J']*1+\
          ['K']*1+['L']*4+['M']*2+['N']*6+['O']*8+\
          ['P']*2+['Q']*1+['R']*6+['S']*4+['T']*6+\
          ['U']*4+['V']*2+['W']*2+['X']*1+['Y']*2+\
          ['Z']*1+['?']*2
            
tiles = [x for x in ascii_uppercase] + ['?']

# potential future improvement: calculate optimal order of letters on the fly
rarity_key = 'ZXKJQ?HYMFPWBCVSGDLURTNAOIE'
# alphabetical_key = '?ABCDEFGHIJKLMNOPQRSTUVWXYZ'
sort_func = lambda x: rarity_key.index(x)

# %%
t0 = time.time()

leaves = {i:sorted(list(set(list(combinations(tilebag,i))))) for i in 
          range(1,maximum_superleave_length+1)}

# turn leaves from lists of letters into strings
# algorith runs faster if leaves non-alphabetical!
for i in range(1,maximum_superleave_length+1):
    leaves[i] = [''.join(sorted(leave, key=sort_func))
                 for leave in leaves[i]]
    
t1 = time.time()
print('Calculated superleaves up to length {} in {} seconds'.format(
    maximum_superleave_length,t1-t0))
# Out:
# Calculated superleaves up to length 5 in 18.967726707458496 seconds

# %% [markdown]
# The bottom creates the full set of leaves for all lengths from 1-5 (6 breaks on my local machine)

# %%
for i in range(1,maximum_superleave_length+1):
    print(i,len(leaves[i]))
# Out:
# 1 27
# 2 373
# 3 3509
# 4 25254
# 5 148150

# %%
column_dict = {
    0:'rack',
    1:'score',
    2:'tiles_remaining'
}
df = pd.read_csv(log_file, header=None, keep_default_na=False)
df.rename(columns=column_dict,inplace=True)

# %%
tile_limit = 1
df = df.loc[df['tiles_remaining']>=tile_limit]

# %%
df = df.iloc[:2000000]

# %% [markdown]
# Order rack (originally alphabetical, but now custom key with rarest letters first for maximum efficiency). Note that this is slower than alphabetical organization because it has to use the index function, but should be rewarded with subsequent performance enhancements.

# %%
t0 = time.time()
df['rack'] = df['rack'].apply(lambda x: ''.join(sorted(x, key=sort_func)))
t1 = time.time()
print(t1-t0)
# Out:
# 6.342475891113281

# %%
tb = time.time()
df_dict = {'': df}

for multiple in range(1,maximum_superleave_length+1):
    t0 = time.time()

    # iterate through all 27 tiles
    for c in leaves[1]:
        if multiple*c in leaves[multiple]:
            condition = df_dict[(multiple-1)*c]['rack'].apply(lambda x: multiple*c in x)
            df_dict[multiple*c] = df_dict[(multiple-1)*c].loc[condition]
            df[multiple*c] = condition
            df[multiple*c].fillna(False, inplace=True)
                        
    t1 = time.time()
    print('Added columns for all duplicates up to length {} in {} seconds'.format(multiple,t1-t0))
    
te = time.time()
print('Added all necessary columns in {} seconds'.format(te-tb))
# Out:
# Added columns for all duplicates up to length 1 in 14.954740047454834 seconds
# Added columns for all duplicates up to length 2 in 8.336242914199829 seconds
# Added columns for all duplicates up to length 3 in 2.7056961059570312 seconds
# Added columns for all duplicates up to length 4 in 1.7734730243682861 seconds
# Added columns for all duplicates up to length 5 in 1.1373162269592285 seconds
# Added all necessary columns in 28.908329010009766 seconds

# %% [markdown]
# Set up dataframe for storing EV of all leaves.

# %%
all_leaves = []

for i in range(1,ev_calculator_max_length+1):
    all_leaves += leaves[i]
    
df_dict = {leave: pd.DataFrame() for leave in all_leaves}
df_dict[''] = df

ev_df = pd.DataFrame(columns=['mean','std','count','ev','synergy'],
                     index=all_leaves)

# %% [markdown]
# To find all of the racks corresponding to a particular leave, we have added columns to the dataframe of plays df marking each letter (A, B, C...) and also for duplicates (AA, BB, CC...) and triplicates where possible (AAA, DDD, EEE...).
#
# If the letters in a given leave are all different, we can look for rows by using df['A']&df['B']. However, if there are duplicates involved, we have to look for df['AA']. The following function gives the correct dataframe columns to be looked up.

# %%
def get_columns(leave):
    letters=list(set(leave))
    tags = []
    
    for l in letters:
        tags += [sum([l==letter for letter in leave])*l]
    
    return tags

# %%
for leave_length in range(3,5):
    print(leave_length)
    t0 = time.time()
    
    for leave in leaves[leave_length]:
        print(leave)
        print(len(df_dict[leave[:-1]]))
        t2 = time.time()
        condition = df_dict[leave[:-1]][get_columns(leave)].all(axis=1)
        t3 = time.time()
        df_dict[leave] = df_dict[leave[:-1]].loc[condition]
        t4 = time.time()
        ev_df.loc[leave]['mean'] = df_dict[leave]['score'].mean()
        t5 = time.time()
        ev_df.loc[leave]['std'] = df_dict[leave]['score'].std()
        t6 = time.time()
        ev_df.loc[leave]['count'] = len(df_dict[leave])
        t7 = time.time()
        print('condition calc time (ms): {:.5f} ({})'.format(1000*(t3-t2),100*(t3-t2)/(t7-t2)))
        print('condition calc time (ms): {:.5f} ({})'.format(1000*(t4-t3),100*(t4-t3)/(t7-t2)))
        print('condition calc time (ms): {:.5f} ({})'.format(1000*(t5-t4),100*(t5-t4)/(t7-t2)))
        print('condition calc time (ms): {:.5f} ({})'.format(1000*(t6-t5),100*(t6-t5)/(t7-t2)))
        print('condition calc time (ms): {:.5f} ({})'.format(1000*(t7-t6),100*(t7-t6)/(t7-t2)))

        
    t1 = time.time()
    print('Calculated mean, std and count in {} seconds'.format(t1-t0))
# Out:
# 3
# A??
# 75605
# condition calc time (ms): 7.39717 (12.684641959156973)
# condition calc time (ms): 20.42484 (35.02442813630696)
# condition calc time (ms): 30.05791 (51.54316318812731)
# condition calc time (ms): 0.29111 (0.49919254277479097)
# condition calc time (ms): 0.14496 (0.24857417363396636)
# AA?
# 217766
# condition calc time (ms): 13.62491 (22.141761205132973)
# condition calc time (ms): 47.21999 (76.73695059202777)
# condition calc time (ms): 0.37622 (0.6114004091500836)
# condition calc time (ms): 0.20790 (0.3378587812286901)
# condition calc time (ms): 0.10586 (0.17202901246047983)
# AAA
# 217766
# condition calc time (ms): 2.86412 (19.238961579731267)
# condition calc time (ms): 11.26599 (75.67623836902035)
# condition calc time (ms): 0.37193 (2.498358450377156)
# condition calc time (ms): 0.26608 (1.7872871991159656)
# condition calc time (ms): 0.11897 (0.799154401755257)
# AAB
# 217766
# condition calc time (ms): 9.30691 (54.06273803753203)
# condition calc time (ms): 7.07102 (41.07471781732567)
# condition calc time (ms): 0.43702 (2.53860535973963)
# condition calc time (ms): 0.26584 (1.5442143895852087)
# condition calc time (ms): 0.13423 (0.7797243958174641)
# AAC
# 217766
# condition calc time (ms): 8.89015 (59.84272187449847)
# condition calc time (ms): 5.27382 (35.49991975605842)
# condition calc time (ms): 0.38004 (2.5581768576472474)
# condition calc time (ms): 0.21005 (1.4138982506820734)
# condition calc time (ms): 0.10180 (0.6852832611137859)
# AAD
# 217766
# condition calc time (ms): 9.17792 (45.04077597201259)
# condition calc time (ms): 10.27894 (50.44403102952017)
# condition calc time (ms): 0.46420 (2.2780722384078067)
# condition calc time (ms): 0.32902 (1.614658289164239)
# condition calc time (ms): 0.12684 (0.6224624708951993)
# AAE
# 217766
# condition calc time (ms): 10.42724 (40.25644093850388)
# condition calc time (ms): 14.50968 (56.01752561187765)
# condition calc time (ms): 0.50211 (1.9384946751226517)
# condition calc time (ms): 0.35715 (1.3788532874329213)
# condition calc time (ms): 0.10586 (0.4086854870628952)
# AAF
# 217766
# condition calc time (ms): 9.25612 (52.81681518264064)
# condition calc time (ms): 7.54809 (43.07053941908714)
# condition calc time (ms): 0.38576 (2.2012108019862593)
# condition calc time (ms): 0.22292 (1.2720223114073872)
# condition calc time (ms): 0.11206 (0.6394122848785797)
# AAG
# 217766
# condition calc time (ms): 11.87396 (57.15548108703636)
# condition calc time (ms): 7.83277 (37.703130738156446)
# condition calc time (ms): 0.53930 (2.595941975762027)
# condition calc time (ms): 0.37885 (1.823586118251928)
# condition calc time (ms): 0.14997 (0.7218600807932427)
# AAH
# 217766
# condition calc time (ms): 10.80608 (45.45354259639974)
# condition calc time (ms): 12.13694 (51.05149676578248)
# condition calc time (ms): 0.42963 (1.80715037857895)
# condition calc time (ms): 0.26536 (1.1161811161811162)
# condition calc time (ms): 0.13590 (0.5716291430577145)
# AAI
# 217766
# condition calc time (ms): 11.60192 (32.03997919396362)
# condition calc time (ms): 23.67473 (65.38033566194142)
# condition calc time (ms): 0.45919 (1.2681147492411722)
# condition calc time (ms): 0.35000 (0.9665589054444657)
# condition calc time (ms): 0.12493 (0.3450114894093324)
# AAJ
# 217766
# condition calc time (ms): 11.10983 (72.1320103403972)
# condition calc time (ms): 3.50404 (22.750421820095664)
# condition calc time (ms): 0.41509 (2.695004721289144)
# condition calc time (ms): 0.23985 (1.557251435736289)
# condition calc time (ms): 0.13328 (0.8653116824816953)
# AAK
# 217766
# condition calc time (ms): 8.39114 (58.94322559035337)
# condition calc time (ms): 5.25904 (36.94188578127617)
# condition calc time (ms): 0.28491 (2.0013398090772063)
# condition calc time (ms): 0.19884 (1.3967509629877743)
# condition calc time (ms): 0.10204 (0.7167978563054764)
# AAL
# 217766
# condition calc time (ms): 9.28712 (46.82413751652843)
# condition calc time (ms): 9.81307 (49.475898545498254)
# condition calc time (ms): 0.38195 (1.9257122250270464)
# condition calc time (ms): 0.24986 (1.259766798894098)
# condition calc time (ms): 0.10204 (0.5144849140521698)
# AAM
# 217766
# condition calc time (ms): 8.76403 (49.31049285005232)
# condition calc time (ms): 8.32009 (46.81270624849086)
# condition calc time (ms): 0.36907 (2.07657017143777)
# condition calc time (ms): 0.21195 (1.1925522496176857)
# condition calc time (ms): 0.10800 (0.607678480401363)
# AAN
# 217766
# condition calc time (ms): 10.09703 (46.888839681133746)
# condition calc time (ms): 10.59294 (49.191762621789195)
# condition calc time (ms): 0.42391 (1.9685562444641276)
# condition calc time (ms): 0.31996 (1.4858281665190434)
# condition calc time (ms): 0.10014 (0.4650132860938884)
# AAO
# 217766
# condition calc time (ms): 9.88293 (32.717169963219625)
# condition calc time (ms): 19.38605 (64.17701936889296)
# condition calc time (ms): 0.47898 (1.5856603892721275)
# condition calc time (ms): 0.34618 (1.1460322972738322)
# condition calc time (ms): 0.11301 (0.37411798134145763)
# AAP
# 217766
# condition calc time (ms): 9.98187 (60.06312316189656)
# condition calc time (ms): 5.97191 (35.93429452693494)
# condition calc time (ms): 0.35310 (2.124668244745714)
# condition calc time (ms): 0.20814 (1.2524209167204647)
# condition calc time (ms): 0.10395 (0.625493149702317)
# AAQ
# 217766
# condition calc time (ms): 8.44407 (64.73588009504661)
# condition calc time (ms): 3.66807 (28.12100164503747)
# condition calc time (ms): 0.50402 (3.864010235788704)
# condition calc time (ms): 0.27966 (2.1440321696216413)
# condition calc time (ms): 0.14806 (1.1350758545055748)
# AAR
# 217766
# condition calc time (ms): 9.74321 (40.84149510293824)
# condition calc time (ms): 13.39388 (56.14431341195283)
# condition calc time (ms): 0.34189 (1.4331401159304418)
# condition calc time (ms): 0.27418 (1.149310413751749)
# condition calc time (ms): 0.10300 (0.43174095542674396)
# AAS
# 217766
# condition calc time (ms): 9.00197 (47.303866295823)
# condition calc time (ms): 9.32574 (49.0052369139793)
# condition calc time (ms): 0.36526 (1.9193665589215465)
# condition calc time (ms): 0.22388 (1.1764263699917312)
# condition calc time (ms): 0.11325 (0.595103861284422)
# AAT
# 217766
# condition calc time (ms): 9.88865 (42.15169161661433)
# condition calc time (ms): 12.64715 (53.91018018842038)
# condition calc time (ms): 0.48018 (2.046810370234865)
# condition calc time (ms): 0.34094 (1.4532963403355794)
# condition calc time (ms): 0.10276 (0.43802148439484945)
# AAU
# 217766
# condition calc time (ms): 9.40299 (39.07985612223665)
# condition calc time (ms): 13.78512 (57.29248208959661)
# condition calc time (ms): 0.49567 (2.0600679753069295)
# condition calc time (ms): 0.27609 (1.1474548895648986)
# condition calc time (ms): 0.10109 (0.4201389232949197)
# AAV
# 217766
# condition calc time (ms): 9.71413 (63.698330310799825)
# condition calc time (ms): 4.85420 (31.830404602588956)
# condition calc time (ms): 0.31900 (2.0918016384216123)
# condition calc time (ms): 0.24486 (1.6055906447376649)
# condition calc time (ms): 0.11802 (0.7738728034519418)
# AAW
# 217766
# condition calc time (ms): 12.94804 (71.4334569752453)
# condition calc time (ms): 4.54688 (25.084839397048377)
# condition calc time (ms): 0.32115 (1.7717622918475258)
# condition calc time (ms): 0.20695 (1.1417146765580197)
# condition calc time (ms): 0.10300 (0.5682266593007655)
# AAX
# 217766
# condition calc time (ms): 9.35698 (71.89887331684528)
# condition calc time (ms): 3.05295 (23.45882568471192)
# condition calc time (ms): 0.29206 (2.2442062837775945)
# condition calc time (ms): 0.19789 (1.5205642575799212)
# condition calc time (ms): 0.11420 (0.8775304570852799)
# AAY
# 217766
# condition calc time (ms): 9.51409 (65.07134121483897)
# condition calc time (ms): 4.45080 (30.44109253974725)
# condition calc time (ms): 0.30422 (2.0807174887892375)
# condition calc time (ms): 0.23508 (1.6078271504280472)
# condition calc time (ms): 0.11683 (0.7990216061964941)
# AAZ
# 217766
# condition calc time (ms): 11.29794 (75.01028904296071)
# condition calc time (ms): 3.17812 (21.10045271789027)
# condition calc time (ms): 0.29087 (1.9311742172412703)
# condition calc time (ms): 0.19217 (1.275841327128249)
# condition calc time (ms): 0.10276 (0.682242694779498)
# AB?
# 102534
# condition calc time (ms): 7.29179 (24.8733317609935)
# condition calc time (ms): 21.29197 (72.62990102391853)
# condition calc time (ms): 0.38505 (1.313445945396433)
# condition calc time (ms): 0.22292 (0.7604160736505664)
# condition calc time (ms): 0.12398 (0.4229051960409567)
# ABB
# 102534
# condition calc time (ms): 4.85420 (67.07296985669576)
# condition calc time (ms): 1.71685 (23.722615714050402)
# condition calc time (ms): 0.35620 (4.921759183001153)
# condition calc time (ms): 0.19193 (2.6519519024872342)
# condition calc time (ms): 0.11802 (1.6307033437654423)
# ABC
# 102534
# condition calc time (ms): 6.10995 (65.91815212079122)
# condition calc time (ms): 2.60019 (28.05257607325668)
# condition calc time (ms): 0.27084 (2.922036165341976)
# condition calc time (ms): 0.18620 (2.0088998636726085)
# condition calc time (ms): 0.10180 (1.0983357769375208)
# ABD
# 102534
# condition calc time (ms): 5.53107 (57.7707498070075)
# condition calc time (ms): 3.41606 (35.6799561720248)
# condition calc time (ms): 0.29922 (3.125233458674702)
# condition calc time (ms): 0.21768 (2.273576213362552)
# condition calc time (ms): 0.11015 (1.150484348930448)
# ABE
# 102534
# condition calc time (ms): 9.08494 (45.88199879590608)
# condition calc time (ms): 9.64594 (48.71523178807947)
# condition calc time (ms): 0.55790 (2.8175797712221553)
# condition calc time (ms): 0.36907 (1.863937387116195)
# condition calc time (ms): 0.14281 (0.7212522576760987)
# ABF
# 102534
# condition calc time (ms): 8.60310 (73.47587049480758)
# condition calc time (ms): 2.54273 (21.71655467318265)
# condition calc time (ms): 0.27490 (2.3477906739971495)
# condition calc time (ms): 0.18620 (1.5903074730197515)
# condition calc time (ms): 0.10180 (0.8694766849928731)
# ABG
# 102534
# condition calc time (ms): 6.24800 (60.21045859755537)
# condition calc time (ms): 3.50404 (33.76757650951199)
# condition calc time (ms): 0.31781 (3.0626780626780628)
# condition calc time (ms): 0.20409 (1.9667309989890636)
# condition calc time (ms): 0.10300 (0.9925558312655087)
# ABH
# 102534
# condition calc time (ms): 5.39923 (50.7587134371848)
# condition calc time (ms): 4.58598 (43.113302700885356)
# condition calc time (ms): 0.32687 (3.0729575254959096)
# condition calc time (ms): 0.21696 (2.039672755799619)
# condition calc time (ms): 0.10800 (1.015353580634316)
# ABI
# 102534
# condition calc time (ms): 6.16908 (31.8999420561439)
# condition calc time (ms): 12.15482 (62.85182399861921)
# condition calc time (ms): 0.52404 (2.7097999087692477)
# condition calc time (ms): 0.35000 (1.8098208671852847)
# condition calc time (ms): 0.14091 (0.7286131692823592)
# ABJ
# 102534
# condition calc time (ms): 5.12910 (71.37690776376908)
# condition calc time (ms): 1.38998 (19.343065693430656)
# condition calc time (ms): 0.26798 (3.7292634372926345)
# condition calc time (ms): 0.23794 (3.3112143331121433)
# condition calc time (ms): 0.16093 (2.2395487723954877)
# ABK
# 102534
# condition calc time (ms): 5.93185 (73.67049626909866)
# condition calc time (ms): 1.58811 (19.723439535710057)
# condition calc time (ms): 0.26178 (3.25121402345138)
# condition calc time (ms): 0.17095 (2.1230605235106004)
# condition calc time (ms): 0.09918 (1.2317896482293025)
# ABL
# 102534
# condition calc time (ms): 5.54514 (50.53011210567481)
# condition calc time (ms): 4.77099 (43.47571043712523)
# condition calc time (ms): 0.31495 (2.8699921786738507)
# condition calc time (ms): 0.22483 (2.048752932997306)
# condition calc time (ms): 0.11802 (1.0754323455288086)
# ABM
# 102534
# condition calc time (ms): 5.59521 (51.53498177346392)
# condition calc time (ms): 4.20189 (38.70174359875269)
# condition calc time (ms): 0.76008 (7.000746629188809)
# condition calc time (ms): 0.19383 (1.7853221485352893)
# condition calc time (ms): 0.10610 (0.9772058500592912)
# ABN
# 102534
# condition calc time (ms): 6.21295 (49.22271963128766)
# condition calc time (ms): 5.74493 (45.514818382727945)
# condition calc time (ms): 0.31805 (2.5197861770650345)
# condition calc time (ms): 0.24104 (1.9096730322434408)
# condition calc time (ms): 0.10514 (0.8330027766759223)
# ABO
# 102534
# condition calc time (ms): 6.42824 (39.805710573714826)
# condition calc time (ms): 9.06491 (56.132813653408924)
# condition calc time (ms): 0.31805 (1.9694688044409012)
# condition calc time (ms): 0.23699 (1.4675052410901468)
# condition calc time (ms): 0.10085 (0.6245017273452033)
# ABP
# 102534
# condition calc time (ms): 5.73635 (63.70135027799841)
# condition calc time (ms): 2.65765 (29.5128408790045)
# condition calc time (ms): 0.29802 (3.309504898067249)
# condition calc time (ms): 0.20123 (2.234577707175007)
# condition calc time (ms): 0.11182 (1.241726237754832)
# ABQ
# 102534
# condition calc time (ms): 5.70393 (67.4219366475031)
# condition calc time (ms): 2.16031 (25.535452598354187)
# condition calc time (ms): 0.28992 (3.426896629466802)
# condition calc time (ms): 0.19693 (2.3278097170555743)
# condition calc time (ms): 0.10896 (1.2879044076203359)
# ABR
# 102534
# condition calc time (ms): 6.08492 (48.48220052429619)
# condition calc time (ms): 5.71680 (45.5491812621101)
# condition calc time (ms): 0.39029 (3.1096842825120627)
# condition calc time (ms): 0.24605 (1.9604118384559857)
# condition calc time (ms): 0.11277 (0.8985220926256601)
# ABS
# 102534
# condition calc time (ms): 8.68416 (68.30951577210158)
# condition calc time (ms): 3.33905 (26.264956303214433)
# condition calc time (ms): 0.32187 (2.531788004951052)
# condition calc time (ms): 0.24295 (1.911031094107498)
# condition calc time (ms): 0.12493 (0.9827088256254454)
# ABT
# 102534
# condition calc time (ms): 6.71577 (49.902561740424474)
# condition calc time (ms): 6.03604 (44.85171668497325)
# condition calc time (ms): 0.36025 (2.676894731247564)
# condition calc time (ms): 0.23866 (1.773376324274528)
# condition calc time (ms): 0.10705 (0.7954505190801828)
# ABU
# 102534
# condition calc time (ms): 5.95212 (42.66427411774759)
# condition calc time (ms): 7.16782 (51.37827907374177)
# condition calc time (ms): 0.44703 (3.204306588054345)
# condition calc time (ms): 0.27084 (1.9413825514825258)
# condition calc time (ms): 0.11325 (0.8117576689737674)
# ABV
# 102534
# condition calc time (ms): 6.13093 (63.30313623159864)
# condition calc time (ms): 2.96307 (30.594259268376742)
# condition calc time (ms): 0.29516 (3.0476096696371426)
# condition calc time (ms): 0.19360 (1.9989168430899513)
# condition calc time (ms): 0.10228 (1.0560779872975234)
# ABW
# 102534
# condition calc time (ms): 5.47504 (66.57389690960747)
# condition calc time (ms): 2.20704 (26.836551284281324)
# condition calc time (ms): 0.25082 (3.0498057633211575)
# condition calc time (ms): 0.18811 (2.287354322490868)
# condition calc time (ms): 0.10300 (1.2523917202991826)
# ABX
# 102534
# condition calc time (ms): 5.23186 (72.27455371846386)
# condition calc time (ms): 1.49608 (20.667281470258875)
# condition calc time (ms): 0.23770 (3.2837099005335615)
# condition calc time (ms): 0.17309 (2.3911468282721824)
# condition calc time (ms): 0.10014 (1.3833080824715105)
# ABY
# 102534
# condition calc time (ms): 5.07689 (46.91651794566726)
# condition calc time (ms): 5.06616 (46.81737061273052)
# condition calc time (ms): 0.35286 (3.260845616586247)
# condition calc time (ms): 0.21243 (1.9631171921475312)
# condition calc time (ms): 0.11277 (1.0421486328684426)
# ABZ
# 102534
# condition calc time (ms): 5.33605 (70.8057831630232)
# condition calc time (ms): 1.65796 (22.000063273118414)
# condition calc time (ms): 0.25797 (3.4230757062861845)
# condition calc time (ms): 0.18096 (2.4012148438735803)
# condition calc time (ms): 0.10324 (1.36986301369863)
# AC?
# 103532
# condition calc time (ms): 5.67389 (20.452396912975473)
# condition calc time (ms): 21.40188 (77.14639302841232)
# condition calc time (ms): 0.36407 (1.3123291909451864)
# condition calc time (ms): 0.19717 (0.7107375513501435)
# condition calc time (ms): 0.10490 (0.3781433163168841)
# ACC
# 103532
# condition calc time (ms): 4.54783 (72.38539769277475)
# condition calc time (ms): 1.17898 (18.76517911353977)
# condition calc time (ms): 0.26608 (4.2349726775956285)
# condition calc time (ms): 0.18311 (2.914389799635701)
# condition calc time (ms): 0.10681 (1.700060716454159)
# ACD
# 103532
# condition calc time (ms): 5.78308 (51.86563174888276)
# condition calc time (ms): 4.67610 (41.93769110697714)
# condition calc time (ms): 0.35381 (3.1731776680137704)
# condition calc time (ms): 0.22817 (2.0463147090897427)
# condition calc time (ms): 0.10896 (0.9771847670365856)
# ACE
# 103532
# condition calc time (ms): 6.66404 (35.41867301941305)
# condition calc time (ms): 11.30009 (60.05879669522023)
# condition calc time (ms): 0.43178 (2.294845151806985)
# condition calc time (ms): 0.30732 (1.6333823305793502)
# condition calc time (ms): 0.11182 (0.5943028029803842)
# ACF
# 103532
# condition calc time (ms): 5.80406 (64.8568003197016)
# condition calc time (ms): 2.54703 (28.46143599307313)
# condition calc time (ms): 0.29898 (3.340881843612628)
# condition calc time (ms): 0.19312 (2.1579858798454774)
# condition calc time (ms): 0.10586 (1.1828959637671506)
# ACG
# 103532
# condition calc time (ms): 5.70607 (41.778095869846034)
# condition calc time (ms): 6.68597 (48.95262367768739)
# condition calc time (ms): 0.54193 (3.967810634360926)
# condition calc time (ms): 0.60511 (4.430401843382327)
# condition calc time (ms): 0.11897 (0.8710679747233181)
# ACH
# 103532
# condition calc time (ms): 5.57184 (64.01512038787082)
# condition calc time (ms): 2.54607 (29.251924288492617)
# condition calc time (ms): 0.29278 (3.363738461117046)
# condition calc time (ms): 0.19002 (2.1831429588845976)
# condition calc time (ms): 0.10324 (1.1860739036349193)
# ACI
# 103532
# condition calc time (ms): 6.45995 (36.30188375894316)
# condition calc time (ms): 10.44393 (58.6899434604357)
# condition calc time (ms): 0.47302 (2.6581634020204183)
# condition calc time (ms): 0.29802 (1.6747501272810097)
# condition calc time (ms): 0.12016 (0.6752592513197031)
# ACJ
# 103532
# condition calc time (ms): 5.72801 (73.30505888814304)
# condition calc time (ms): 1.48582 (19.015072923658998)
# condition calc time (ms): 0.28610 (3.6614389455055836)
# condition calc time (ms): 0.20003 (2.559956062732654)
# condition calc time (ms): 0.11396 (1.4584731799597241)
# ACK
# 103532
# condition calc time (ms): 5.92685 (68.78147307841293)
# condition calc time (ms): 1.98030 (22.981572685518234)
# condition calc time (ms): 0.35787 (4.153062918488185)
# condition calc time (ms): 0.21601 (2.506778816888938)
# condition calc time (ms): 0.13590 (1.577112500691716)
# ACL
# 103532
# condition calc time (ms): 6.20174 (51.71166156415252)
# condition calc time (ms): 5.04518 (42.06790982465906)
# condition calc time (ms): 0.35977 (2.999880720448491)
# condition calc time (ms): 0.25821 (2.1529959047353984)
# condition calc time (ms): 0.12803 (1.0675519860045326)
# ACM
# 103532
# condition calc time (ms): 6.09303 (50.16587166048328)
# condition calc time (ms): 5.31507 (43.760673694128734)
# condition calc time (ms): 0.37575 (3.093653691380563)
# condition calc time (ms): 0.20909 (1.721531908211138)
# condition calc time (ms): 0.15283 (1.2582690457962822)
# ACN
# 103532
# condition calc time (ms): 6.22582 (48.79566476688779)
# condition calc time (ms): 5.84435 (45.80584882743156)
# condition calc time (ms): 0.33092 (2.593665327478277)
# condition calc time (ms): 0.24891 (1.9508549004951883)
# condition calc time (ms): 0.10896 (0.8539661777071849)
# ACO
# 103532
# condition calc time (ms): 6.38986 (38.549277947183704)
# condition calc time (ms): 9.44209 (56.963063114895576)
# condition calc time (ms): 0.38505 (2.3229388412634484)
# condition calc time (ms): 0.25201 (1.5203383004430124)
# condition calc time (ms): 0.10681 (0.644381796214257)
# ACP
# 103532
# condition calc time (ms): 5.77617 (65.03892617449664)
# condition calc time (ms): 2.45976 (27.696644295302015)
# condition calc time (ms): 0.27227 (3.065771812080537)
# condition calc time (ms): 0.26679 (3.004026845637584)
# condition calc time (ms): 0.10610 (1.1946308724832215)
# ACQ
# 103532
# condition calc time (ms): 5.53799 (70.1392034302624)
# condition calc time (ms): 1.81890 (23.03650692997554)
# condition calc time (ms): 0.25606 (3.243047377479844)
# condition calc time (ms): 0.18191 (2.3039526527161276)
# condition calc time (ms): 0.10085 (1.277289609566084)
# ACR
# 103532
# condition calc time (ms): 5.74708 (38.487945074245566)
# condition calc time (ms): 8.33702 (55.832668050455055)
# condition calc time (ms): 0.42796 (2.8660386396295703)
# condition calc time (ms): 0.28706 (1.922401405077439)
# condition calc time (ms): 0.13304 (0.8909468305923679)
# ACS
# 103532
# condition calc time (ms): 5.73611 (61.426711262031816)
# condition calc time (ms): 3.03197 (32.46865984119284)
# condition calc time (ms): 0.26321 (2.818699415324125)
# condition calc time (ms): 0.20194 (2.1625347869379836)
# condition calc time (ms): 0.10490 (1.1233946945132383)
# ACT
# 103532
# condition calc time (ms): 5.98502 (39.32358976768958)
# condition calc time (ms): 8.40187 (55.203095383554995)
# condition calc time (ms): 0.45729 (3.0045271550981405)
# condition calc time (ms): 0.26774 (1.759167880696148)
# condition calc time (ms): 0.10800 (0.7096198129611354)
# ACU
# 103532
# condition calc time (ms): 5.97310 (50.07995842162076)
# condition calc time (ms): 5.29790 (44.41890217087115)
# condition calc time (ms): 0.30589 (2.5646663734857875)
# condition calc time (ms): 0.24104 (2.0209491064646383)
# condition calc time (ms): 0.10920 (0.91552392755767)
# ACV
# 103532
# condition calc time (ms): 5.63264 (57.9797285689744)
# condition calc time (ms): 3.47209 (35.74005448253859)
# condition calc time (ms): 0.31209 (3.2125064421920633)
# condition calc time (ms): 0.19479 (2.005055586914374)
# condition calc time (ms): 0.10324 (1.0626549193805679)
# ACW
# 103532
# condition calc time (ms): 7.80106 (71.70721016874863)
# condition calc time (ms): 2.48599 (22.851194389655927)
# condition calc time (ms): 0.27895 (2.5641025641025643)
# condition calc time (ms): 0.20504 (1.8847249616480386)
# condition calc time (ms): 0.10800 (0.9927679158448389)
# ACX
# 103532
# condition calc time (ms): 5.31912 (68.75828273800352)
# condition calc time (ms): 1.79195 (23.163928868616512)
# condition calc time (ms): 0.30017 (3.8801738219249855)
# condition calc time (ms): 0.19670 (2.542607945264585)
# condition calc time (ms): 0.12803 (1.6550066261904028)
# ACY
# 103532
# condition calc time (ms): 5.66101 (62.670573019769314)
# condition calc time (ms): 2.74801 (30.422044500752236)
# condition calc time (ms): 0.30208 (3.3441549871987752)
# condition calc time (ms): 0.20981 (2.3226964394119354)
# condition calc time (ms): 0.11206 (1.2405310528677382)
# ACZ
# 103532
# condition calc time (ms): 5.63312 (69.38098314441768)
# condition calc time (ms): 1.82390 (22.464321371938684)
# condition calc time (ms): 0.33593 (4.137546250073413)
# condition calc time (ms): 0.21029 (2.590004111117637)
# condition calc time (ms): 0.11587 (1.4271451224525753)
# AD?
# 187719
# condition calc time (ms): 12.20798 (26.474055384360845)
# condition calc time (ms): 33.10800 (71.79750997869833)
# condition calc time (ms): 0.47278 (1.0252724753376212)
# condition calc time (ms): 0.21815 (0.47308336607863005)
# condition calc time (ms): 0.10610 (0.23007879552457966)
# ADD
# 187719
# condition calc time (ms): 7.68399 (51.087404495450656)
# condition calc time (ms): 6.67500 (44.379101543924165)
# condition calc time (ms): 0.36192 (2.406239102177979)
# condition calc time (ms): 0.21410 (1.4234536981263672)
# condition calc time (ms): 0.10586 (0.7038011603208318)
# ADE
# 187719
# condition calc time (ms): 10.83279 (38.36560301953069)
# condition calc time (ms): 16.54315 (58.589534657896294)
# condition calc time (ms): 0.43702 (1.5477627945857855)
# condition calc time (ms): 0.31877 (1.128946457371083)
# condition calc time (ms): 0.10395 (0.36815307061614977)
# ADF
# 187719
# condition calc time (ms): 9.26685 (54.03737070403737)
# condition calc time (ms): 7.10797 (41.44839283728172)
# condition calc time (ms): 0.44799 (2.6123345567790013)
# condition calc time (ms): 0.21911 (1.2776665554443332)
# condition calc time (ms): 0.10705 (0.6242353464575687)
# ADG
# 187719
# condition calc time (ms): 10.09512 (53.568988638951446)
# condition calc time (ms): 7.93171 (42.089015966195184)
# condition calc time (ms): 0.43130 (2.288656663545963)
# condition calc time (ms): 0.28205 (1.4966726550441538)
# condition calc time (ms): 0.10490 (0.5566660762632525)
# ADH
# 187719
# condition calc time (ms): 9.26733 (50.54945054945055)
# condition calc time (ms): 8.32486 (45.40867416607062)
# condition calc time (ms): 0.36812 (2.00793289550686)
# condition calc time (ms): 0.25702 (1.401911697769686)
# condition calc time (ms): 0.11587 (0.6320306912022888)
# ADI
# 187719
# condition calc time (ms): 10.98323 (35.470532978117255)
# condition calc time (ms): 18.42308 (59.49766696952431)
# condition calc time (ms): 0.97275 (3.141506383109783)
# condition calc time (ms): 0.46015 (1.486055715539677)
# condition calc time (ms): 0.12517 (0.40423795370897947)
# ADJ
# 187719
# condition calc time (ms): 9.38511 (65.86022854657097)
# condition calc time (ms): 4.08792 (28.687112048051667)
# condition calc time (ms): 0.35501 (2.4912580100051867)
# condition calc time (ms): 0.27895 (1.9575365155850022)
# condition calc time (ms): 0.14305 (1.0038648797871808)
# ADK
# 187719
# condition calc time (ms): 10.05387 (54.49247270142793)
# condition calc time (ms): 7.34901 (39.83200878723267)
# condition calc time (ms): 0.63419 (3.437358661239258)
# condition calc time (ms): 0.29182 (1.581701880209343)
# condition calc time (ms): 0.12112 (0.6564579698908057)
# ADL
# 187719
# condition calc time (ms): 10.52809 (53.89394031854519)
# condition calc time (ms): 8.31389 (42.559345822908405)
# condition calc time (ms): 0.33808 (1.7306401415756392)
# condition calc time (ms): 0.24796 (1.2692988344419356)
# condition calc time (ms): 0.10681 (0.5467748825288339)
# ADM
# 187719
# condition calc time (ms): 10.71382 (59.18603885413237)
# condition calc time (ms): 6.76608 (37.377675337504115)
# condition calc time (ms): 0.31900 (1.7622653934804082)
# condition calc time (ms): 0.20099 (1.110306223246625)
# condition calc time (ms): 0.10204 (0.5637141916364834)
# ADN
# 187719
# condition calc time (ms): 10.78391 (40.3877062647332)
# condition calc time (ms): 14.98294 (56.113829559254235)
# condition calc time (ms): 0.52190 (1.9546039002785913)
# condition calc time (ms): 0.29612 (1.109007786270448)
# condition calc time (ms): 0.11611 (0.4348524894635331)
# ADO
# 187719
# condition calc time (ms): 11.20806 (42.91974801424267)
# condition calc time (ms): 14.06002 (53.84095681548434)
# condition calc time (ms): 0.37193 (1.4242673240208161)
# condition calc time (ms): 0.37003 (1.4169633890258377)
# condition calc time (ms): 0.10395 (0.39806445722633066)
# ADP
# 187719
# condition calc time (ms): 9.66787 (61.88666575095768)
# condition calc time (ms): 5.16915 (33.08914426995101)
# condition calc time (ms): 0.43178 (2.7639149611586773)
# condition calc time (ms): 0.24605 (1.5750194588159883)
# condition calc time (ms): 0.10705 (0.685255559116646)
# ADQ
# 187719
# condition calc time (ms): 9.41896 (70.33792685966598)
# condition calc time (ms): 3.37505 (25.203859986468682)
# condition calc time (ms): 0.28610 (2.1365238756543103)
# condition calc time (ms): 0.19693 (1.4706406010753836)
# condition calc time (ms): 0.11396 (0.8510486771356337)
# ADR
# 187719
# condition calc time (ms): 9.84192 (42.83757419783321)
# condition calc time (ms): 12.33578 (53.69225021792371)
# condition calc time (ms): 0.43106 (1.8762193350213774)
# condition calc time (ms): 0.26608 (1.1581088373251422)
# condition calc time (ms): 0.10014 (0.4358474118965589)
# ADS
# 187719
# condition calc time (ms): 10.01430 (51.73675264208115)
# condition calc time (ms): 8.57592 (44.305668465006285)
# condition calc time (ms): 0.43201 (2.2319119059936443)
# condition calc time (ms): 0.22984 (1.1873968418200183)
# condition calc time (ms): 0.10419 (0.5382701450989087)
# ADT
# 187719
# condition calc time (ms): 10.66113 (45.17589056596149)
# condition calc time (ms): 12.03585 (51.00119213594391)
# condition calc time (ms): 0.48614 (2.059970499686812)
# condition calc time (ms): 0.29898 (1.2668970115778626)
# condition calc time (ms): 0.11706 (0.4960497868299287)
# ADU
# 187719
# condition calc time (ms): 11.23810 (48.083239824543504)
# condition calc time (ms): 11.36398 (48.62185045394267)
# condition calc time (ms): 0.39911 (1.7076405182087115)
# condition calc time (ms): 0.26488 (1.1333265326940734)
# condition calc time (ms): 0.10610 (0.45394267061103744)
# ADV
# 187719
# condition calc time (ms): 10.94103 (51.944082856981154)
# condition calc time (ms): 9.41992 (44.72239515535684)
# condition calc time (ms): 0.38314 (1.8190050370705755)
# condition calc time (ms): 0.21505 (1.0209972267813685)
# condition calc time (ms): 0.10395 (0.4935197238100628)
# ADW
# 187719
# condition calc time (ms): 9.87172 (68.2282569291105)
# condition calc time (ms): 4.00805 (27.701611574333455)
# condition calc time (ms): 0.28610 (1.9773918201891705)
# condition calc time (ms): 0.20099 (1.3891177536828923)
# condition calc time (ms): 0.10180 (0.7036219226839798)
# ADX
# 187719
# condition calc time (ms): 11.30509 (78.6873547958845)
# condition calc time (ms): 2.50292 (17.42117490872884)
# condition calc time (ms): 0.27394 (1.906737470959177)
# condition calc time (ms): 0.18311 (1.2744772651842018)
# condition calc time (ms): 0.10204 (0.7102555592432791)
# ADY
# 187719
# condition calc time (ms): 9.13572 (64.09407199250636)
# condition calc time (ms): 4.34995 (30.51819884919042)
# condition calc time (ms): 0.38338 (2.6896828582898435)
# condition calc time (ms): 0.25392 (1.781413087113609)
# condition calc time (ms): 0.13065 (0.9166332128997725)
# ADZ
# 187719
# condition calc time (ms): 9.05704 (72.84791071394328)
# condition calc time (ms): 2.81000 (22.60149193625712)
# condition calc time (ms): 0.27609 (2.220645482961628)
# condition calc time (ms): 0.18978 (1.526454062553934)
# condition calc time (ms): 0.09990 (0.8034978042840432)
# AE?
# 466004
# condition calc time (ms): 28.63622 (25.98541377751143)
# condition calc time (ms): 80.65200 (73.18618744009848)
# condition calc time (ms): 0.47183 (0.4281538757769619)
# condition calc time (ms): 0.32902 (0.29856106547357625)
# condition calc time (ms): 0.11206 (0.10168384113955134)
# AEE
# 466004
# condition calc time (ms): 21.64721 (41.51027070027294)
# condition calc time (ms): 29.44303 (56.459362955986634)
# condition calc time (ms): 0.51904 (0.9952955483726438)
# condition calc time (ms): 0.42582 (0.8165355302680486)
# condition calc time (ms): 0.11396 (0.21853526509973528)
# AEF
# 466004
# condition calc time (ms): 26.59488 (71.27558290362362)
# condition calc time (ms): 9.84812 (26.393441575453192)
# condition calc time (ms): 0.44274 (1.1865738877067877)
# condition calc time (ms): 0.31209 (0.8364163807260018)
# condition calc time (ms): 0.11492 (0.30798525249039943)
# AEG
# 466004
# condition calc time (ms): 25.80261 (59.31252192213258)
# condition calc time (ms): 16.70218 (38.39332690284111)
# condition calc time (ms): 0.42987 (0.9881401262714837)
# condition calc time (ms): 0.41318 (0.9497763942476324)
# condition calc time (ms): 0.15497 (0.35623465450719044)
# AEH
# 466004
# condition calc time (ms): 23.29779 (66.3588148610932)
# condition calc time (ms): 10.99896 (31.328222087914327)
# condition calc time (ms): 0.40913 (1.165309628744304)
# condition calc time (ms): 0.28491 (0.8115064139565521)
# condition calc time (ms): 0.11802 (0.3361470082916262)
# AEI
# 466004
# condition calc time (ms): 27.86207 (34.872103987872855)
# condition calc time (ms): 50.62294 (63.35955310996789)
# condition calc time (ms): 0.69714 (0.8725336898268062)
# condition calc time (ms): 0.60272 (0.7543656524904809)
# condition calc time (ms): 0.11301 (0.14144355984196516)
# AEJ
# 466004
# condition calc time (ms): 23.28587 (76.02515801600399)
# condition calc time (ms): 6.58917 (21.512750256873307)
# condition calc time (ms): 0.39196 (1.2796961110938132)
# condition calc time (ms): 0.24819 (0.8103185229006445)
# condition calc time (ms): 0.11396 (0.3720770931282498)
# AEK
# 466004
# condition calc time (ms): 23.16189 (71.44391004427187)
# condition calc time (ms): 8.42309 (25.981408757298976)
# condition calc time (ms): 0.41699 (1.286237479592287)
# condition calc time (ms): 0.28181 (0.8692582623659709)
# condition calc time (ms): 0.13590 (0.4191854564708997)
# AEL
# 466004
# condition calc time (ms): 24.59311 (52.077527363786906)
# condition calc time (ms): 21.72899 (46.012561088896966)
# condition calc time (ms): 0.44107 (0.9340037965992164)
# condition calc time (ms): 0.35381 (0.7492225049476958)
# condition calc time (ms): 0.10705 (0.22668524576921523)
# AEM
# 466004
# condition calc time (ms): 26.51811 (64.23175985493353)
# condition calc time (ms): 13.01503 (31.524814913202665)
# condition calc time (ms): 0.86188 (2.0876404753929845)
# condition calc time (ms): 0.61584 (1.4916667629156513)
# condition calc time (ms): 0.27418 (0.664117993555168)
# AEN
# 466004
# condition calc time (ms): 25.73609 (43.74209809705968)
# condition calc time (ms): 31.88705 (54.19651829999676)
# condition calc time (ms): 0.60892 (1.0349466722857976)
# condition calc time (ms): 0.48018 (0.8161247447077512)
# condition calc time (ms): 0.12374 (0.21031218595001136)
# AEO
# 466004
# condition calc time (ms): 28.03278 (40.16451402434234)
# condition calc time (ms): 40.44199 (57.94405293416364)
# condition calc time (ms): 0.64516 (0.9243665902623821)
# condition calc time (ms): 0.56887 (0.8150549461810952)
# condition calc time (ms): 0.10610 (0.15201150505053956)
# AEP
# 466004
# condition calc time (ms): 22.45998 (67.48572615713047)
# condition calc time (ms): 10.03695 (30.158104748873495)
# condition calc time (ms): 0.41127 (1.23575302132659)
# condition calc time (ms): 0.26703 (0.8023439906584235)
# condition calc time (ms): 0.10586 (0.3180720820110179)
# AEQ
# 466004
# condition calc time (ms): 22.15195 (65.93057250716699)
# condition calc time (ms): 10.70905 (31.873208254094404)
# condition calc time (ms): 0.38910 (1.158071017002072)
# condition calc time (ms): 0.24176 (0.7195367715931992)
# condition calc time (ms): 0.10705 (0.3186114501433397)
# AER
# 466004
# condition calc time (ms): 24.98317 (45.3908297416127)
# condition calc time (ms): 28.99504 (52.679820666652226)
# condition calc time (ms): 0.55194 (1.0027939615776136)
# condition calc time (ms): 0.40698 (0.7394251803079855)
# condition calc time (ms): 0.10300 (0.1871304498494726)
# AES
# 466004
# condition calc time (ms): 25.06804 (56.671086389409915)
# condition calc time (ms): 18.27216 (41.3076989414225)
# condition calc time (ms): 0.44203 (0.999288532436453)
# condition calc time (ms): 0.33998 (0.7686005648621262)
# condition calc time (ms): 0.11206 (0.25332557186900373)
# AET
# 466004
# condition calc time (ms): 26.69311 (46.095667067406666)
# condition calc time (ms): 30.08103 (51.94619653826518)
# condition calc time (ms): 0.53596 (0.9255447044679764)
# condition calc time (ms): 0.48709 (0.8411422736779697)
# condition calc time (ms): 0.11086 (0.19144941618221042)
# AEU
# 466004
# condition calc time (ms): 28.12719 (50.73343166893871)
# condition calc time (ms): 26.21794 (47.28967863178763)
# condition calc time (ms): 0.56505 (1.0191926446113952)
# condition calc time (ms): 0.42295 (0.7628893466416097)
# condition calc time (ms): 0.10800 (0.19480770802065908)
# AEV
# 466004
# condition calc time (ms): 22.91799 (62.202737243990036)
# condition calc time (ms): 13.12208 (35.61523279515967)
# condition calc time (ms): 0.41389 (1.123370110330993)
# condition calc time (ms): 0.28706 (0.7791115281327855)
# condition calc time (ms): 0.10300 (0.2795483223865144)
# AEW
# 466004
# condition calc time (ms): 23.21815 (65.54534746760895)
# condition calc time (ms): 11.39212 (32.160188457008246)
# condition calc time (ms): 0.41485 (1.171125694093892)
# condition calc time (ms): 0.29016 (0.8191149251219922)
# condition calc time (ms): 0.10777 (0.30422345616691904)
# AEX
# 466004
# condition calc time (ms): 22.81070 (75.81340433287374)
# condition calc time (ms): 6.55007 (21.769758633258846)
# condition calc time (ms): 0.37408 (1.243284362668188)
# condition calc time (ms): 0.23293 (0.7741802564224473)
# condition calc time (ms): 0.12016 (0.39937241477677937)
# AEY
# 466004
# condition calc time (ms): 24.31107 (68.19233598608974)
# condition calc time (ms): 10.43892 (29.281080719588044)
# condition calc time (ms): 0.45490 (1.2759981274660603)
# condition calc time (ms): 0.31209 (0.8754096167993045)
# condition calc time (ms): 0.13375 (0.3751755500568448)
# AEZ
# 466004
# condition calc time (ms): 22.43090 (70.76015914680465)
# condition calc time (ms): 8.29315 (26.161448266006815)
# condition calc time (ms): 0.53811 (1.697515775539828)
# condition calc time (ms): 0.30375 (0.9581901187584142)
# condition calc time (ms): 0.13399 (0.4226866928902895)
# AF?
# 94546
# condition calc time (ms): 6.87790 (25.48319847355217)
# condition calc time (ms): 19.47999 (72.17501148369315)
# condition calc time (ms): 0.33617 (1.2455390268895092)
# condition calc time (ms): 0.19002 (0.7040387265467651)
# condition calc time (ms): 0.10586 (0.39221228931839863)
# AFF
# 94546
# condition calc time (ms): 5.18990 (64.71252749866223)
# condition calc time (ms): 2.07090 (25.8219870384684)
# condition calc time (ms): 0.35000 (4.364112016172186)
# condition calc time (ms): 0.24104 (3.0055294607289373)
# condition calc time (ms): 0.16809 (2.09584398596825)
# AFG
# 94546
# condition calc time (ms): 5.16820 (60.643446635893135)
# condition calc time (ms): 2.70104 (31.6939432088404)
# condition calc time (ms): 0.31781 (3.7291928941110646)
# condition calc time (ms): 0.22197 (2.604560078332634)
# condition calc time (ms): 0.11325 (1.3288571828227724)
# AFH
# 94546
# condition calc time (ms): 6.02388 (67.53448091521437)
# condition calc time (ms): 2.29001 (25.673580669303966)
# condition calc time (ms): 0.29802 (3.341173954880787)
# condition calc time (ms): 0.19979 (2.2399230193520796)
# condition calc time (ms): 0.10800 (1.2108414412487971)
# AFI
# 94546
# condition calc time (ms): 5.71203 (31.77200753255709)
# condition calc time (ms): 11.46579 (63.77609208816275)
# condition calc time (ms): 0.42009 (2.3366840834946823)
# condition calc time (ms): 0.25296 (1.4070498368830067)
# condition calc time (ms): 0.12732 (0.7081664589024746)
# AFJ
# 94546
# condition calc time (ms): 5.08118 (68.65537014367631)
# condition calc time (ms): 1.47676 (19.953611236389406)
# condition calc time (ms): 0.32520 (4.394046775336641)
# condition calc time (ms): 0.26584 (3.5919077379034854)
# condition calc time (ms): 0.25201 (3.4050641066941565)
# AFK
# 94546
# condition calc time (ms): 5.96094 (74.53049543909854)
# condition calc time (ms): 1.46794 (18.353902104572825)
# condition calc time (ms): 0.28419 (3.5533297561557267)
# condition calc time (ms): 0.18096 (2.2625648363441244)
# condition calc time (ms): 0.10395 (1.2997078638287725)
# AFL
# 94546
# condition calc time (ms): 5.30195 (45.30046852719495)
# condition calc time (ms): 5.62906 (48.095335098798124)
# condition calc time (ms): 0.40317 (3.444693420248523)
# condition calc time (ms): 0.25082 (2.143002648197189)
# condition calc time (ms): 0.11897 (1.016500305561214)
# AFM
# 94546
# condition calc time (ms): 5.33295 (64.76719944405838)
# condition calc time (ms): 2.32005 (28.17639564512393)
# condition calc time (ms): 0.27800 (3.3761871670141304)
# condition calc time (ms): 0.19002 (2.3077368542969654)
# condition calc time (ms): 0.11301 (1.3724808895066019)
# AFN
# 94546
# condition calc time (ms): 5.87392 (39.89668350822645)
# condition calc time (ms): 8.00300 (54.357753595025265)
# condition calc time (ms): 0.44084 (2.994235004534266)
# condition calc time (ms): 0.28324 (1.92382432957637)
# condition calc time (ms): 0.12183 (0.8275035626376473)
# AFO
# 94546
# condition calc time (ms): 7.34377 (52.03567929182012)
# condition calc time (ms): 6.12307 (43.386154002094806)
# condition calc time (ms): 0.31304 (2.2181302159002603)
# condition calc time (ms): 0.23007 (1.630232793864243)
# condition calc time (ms): 0.10300 (0.7298036963205731)
# AFP
# 94546
# condition calc time (ms): 5.58186 (56.89982015262723)
# condition calc time (ms): 3.48902 (35.56603315024547)
# condition calc time (ms): 0.37098 (3.781655567977446)
# condition calc time (ms): 0.22507 (2.2942691877703787)
# condition calc time (ms): 0.14305 (1.458221941379478)
# AFQ
# 94546
# condition calc time (ms): 5.22614 (65.45041951569078)
# condition calc time (ms): 2.15387 (26.974411035800664)
# condition calc time (ms): 0.29588 (3.7054731121793916)
# condition calc time (ms): 0.19717 (2.46932011585202)
# condition calc time (ms): 0.11182 (1.400376220477143)
# AFR
# 94546
# condition calc time (ms): 6.38318 (46.467188503393096)
# condition calc time (ms): 6.69193 (48.714789037957544)
# condition calc time (ms): 0.32783 (2.3864484440356146)
# condition calc time (ms): 0.22912 (1.667910512522346)
# condition calc time (ms): 0.10490 (0.7636635020913967)
# AFS
# 94546
# condition calc time (ms): 5.93305 (57.46316907587863)
# condition calc time (ms): 3.72982 (36.124324573962035)
# condition calc time (ms): 0.33903 (3.283609661478779)
# condition calc time (ms): 0.21386 (2.071306516418048)
# condition calc time (ms): 0.10920 (1.057590172262504)
# AFT
# 94546
# condition calc time (ms): 5.76782 (49.938072826356205)
# condition calc time (ms): 4.82106 (41.74097927503922)
# condition calc time (ms): 0.42105 (3.6454462884980594)
# condition calc time (ms): 0.37098 (3.2119560729914953)
# condition calc time (ms): 0.16904 (1.4635455371150194)
# AFU
# 94546
# condition calc time (ms): 7.93028 (61.379195807421894)
# condition calc time (ms): 4.36091 (33.75283718698677)
# condition calc time (ms): 0.30303 (2.3454079090623905)
# condition calc time (ms): 0.21982 (1.7013895296266908)
# condition calc time (ms): 0.10610 (0.8211695669022532)
# AFV
# 94546
# condition calc time (ms): 6.08206 (67.70529221296248)
# condition calc time (ms): 2.32601 (25.89309411327565)
# condition calc time (ms): 0.28181 (3.1371091883857956)
# condition calc time (ms): 0.18907 (2.1046764690270185)
# condition calc time (ms): 0.10419 (1.159828016349063)
# AFW
# 94546
# condition calc time (ms): 5.15485 (65.19418646725364)
# condition calc time (ms): 2.16103 (27.330840670606683)
# condition calc time (ms): 0.27990 (3.539983114220239)
# condition calc time (ms): 0.20123 (2.5449282354360148)
# condition calc time (ms): 0.10991 (1.3900615124834157)
# AFX
# 94546
# condition calc time (ms): 5.79095 (73.37623104344148)
# condition calc time (ms): 1.50990 (19.13177451513504)
# condition calc time (ms): 0.27609 (3.498278049664673)
# condition calc time (ms): 0.20194 (2.558757778986164)
# condition calc time (ms): 0.11325 (1.4349586127726421)
# AFY
# 94546
# condition calc time (ms): 4.99988 (57.06239286005823)
# condition calc time (ms): 2.85530 (32.58686838453375)
# condition calc time (ms): 0.47898 (5.466517917879786)
# condition calc time (ms): 0.29802 (3.401267992707681)
# condition calc time (ms): 0.12994 (1.4829528448205491)
# AFZ
# 94546
# condition calc time (ms): 4.91595 (71.09264558838741)
# condition calc time (ms): 1.44124 (20.842671447781264)
# condition calc time (ms): 0.27275 (3.9444195428059166)
# condition calc time (ms): 0.18096 (2.6169706582077716)
# condition calc time (ms): 0.10395 (1.5032927628176396)
# AG?
# 175057
# condition calc time (ms): 10.82587 (27.216547987244958)
# condition calc time (ms): 28.32389 (71.20705363350835)
# condition calc time (ms): 0.32902 (0.8271596058404661)
# condition calc time (ms): 0.19503 (0.4903018533170299)
# condition calc time (ms): 0.10300 (0.2589369200891894)
# AGG
# 175057
# condition calc time (ms): 7.12395 (60.11830509838638)
# condition calc time (ms): 3.92318 (33.10731962496479)
# condition calc time (ms): 0.42486 (3.5853687980362965)
# condition calc time (ms): 0.24986 (2.108567059675667)
# condition calc time (ms): 0.12803 (1.0804394189368638)
# AGH
# 175057
# condition calc time (ms): 11.71112 (72.78546661529799)
# condition calc time (ms): 3.77488 (23.461162315146844)
# condition calc time (ms): 0.29278 (1.8196366653824496)
# condition calc time (ms): 0.20504 (1.274338381293898)
# condition calc time (ms): 0.10610 (0.6593960228788193)
# AGI
# 175057
# condition calc time (ms): 10.57601 (36.179531515072426)
# condition calc time (ms): 17.80915 (60.923430771238415)
# condition calc time (ms): 0.43797 (1.4982709121753883)
# condition calc time (ms): 0.30375 (1.0390839096959414)
# condition calc time (ms): 0.10514 (0.3596828918178259)
# AGJ
# 175057
# condition calc time (ms): 9.61375 (64.60052227687082)
# condition calc time (ms): 4.58336 (30.798314615742)
# condition calc time (ms): 0.34785 (2.337429308383665)
# condition calc time (ms): 0.21696 (1.4578894246944039)
# condition calc time (ms): 0.11992 (0.8058443743091046)
# AGK
# 175057
# condition calc time (ms): 9.70721 (68.4757564035722)
# condition calc time (ms): 3.73912 (26.376158361223702)
# condition calc time (ms): 0.34881 (2.460519013101465)
# condition calc time (ms): 0.24986 (1.7625590743201198)
# condition calc time (ms): 0.13113 (0.9250071477825056)
# AGL
# 175057
# condition calc time (ms): 9.87101 (46.56357195073947)
# condition calc time (ms): 10.51092 (49.58218523308778)
# condition calc time (ms): 0.36001 (1.6982511387279986)
# condition calc time (ms): 0.28086 (1.3248608221334983)
# condition calc time (ms): 0.17619 (0.8311308553112523)
# AGM
# 175057
# condition calc time (ms): 11.10506 (69.73380842590652)
# condition calc time (ms): 4.03881 (25.361559421504925)
# condition calc time (ms): 0.39506 (2.480761745066922)
# condition calc time (ms): 0.27013 (1.6962601431266282)
# condition calc time (ms): 0.11587 (0.7276102643950055)
# AGN
# 175057
# condition calc time (ms): 10.57291 (41.969279691093384)
# condition calc time (ms): 13.33618 (52.93811457179902)
# condition calc time (ms): 0.57602 (2.2865146740107702)
# condition calc time (ms): 0.54383 (2.1587499881699364)
# condition calc time (ms): 0.16308 (0.6473410749268902)
# AGO
# 175057
# condition calc time (ms): 13.38696 (44.859268017928045)
# condition calc time (ms): 14.67109 (49.16231914162679)
# condition calc time (ms): 0.43392 (1.4540573793412002)
# condition calc time (ms): 0.86927 (2.9129083544384704)
# condition calc time (ms): 0.48089 (1.611447106665495)
# AGP
# 175057
# condition calc time (ms): 9.71889 (60.975573272702796)
# condition calc time (ms): 5.22804 (32.80032309694404)
# condition calc time (ms): 0.62990 (3.951954287765695)
# condition calc time (ms): 0.24128 (1.513769015601394)
# condition calc time (ms): 0.12088 (0.7583803269860739)
# AGQ
# 175057
# condition calc time (ms): 9.18293 (71.47416864608076)
# condition calc time (ms): 3.07202 (23.910703681710213)
# condition calc time (ms): 0.28586 (2.2249851543942993)
# condition calc time (ms): 0.20099 (1.564355700712589)
# condition calc time (ms): 0.10610 (0.8257868171021377)
# AGR
# 175057
# condition calc time (ms): 10.34093 (45.762729747409736)
# condition calc time (ms): 11.44218 (50.63622359619321)
# condition calc time (ms): 0.36979 (1.6364557175715884)
# condition calc time (ms): 0.33426 (1.4792462385785732)
# condition calc time (ms): 0.10967 (0.48534470024689275)
# AGS
# 175057
# condition calc time (ms): 9.48000 (52.56742464304601)
# condition calc time (ms): 7.87497 (43.66737176097303)
# condition calc time (ms): 0.33689 (1.8680592279217345)
# condition calc time (ms): 0.23603 (1.3088313061872026)
# condition calc time (ms): 0.10610 (0.5883130618720254)
# AGT
# 175057
# condition calc time (ms): 10.76579 (45.87058106460788)
# condition calc time (ms): 11.96218 (50.968102397399434)
# condition calc time (ms): 0.36311 (1.5471353108492483)
# condition calc time (ms): 0.27180 (1.1580658268996342)
# condition calc time (ms): 0.10705 (0.4561154002438033)
# AGU
# 175057
# condition calc time (ms): 11.38496 (42.94901198924296)
# condition calc time (ms): 14.29725 (53.935403793745444)
# condition calc time (ms): 0.41294 (1.5577921085057969)
# condition calc time (ms): 0.30303 (1.1431603752372215)
# condition calc time (ms): 0.10991 (0.4146317332685752)
# AGV
# 175057
# condition calc time (ms): 9.92608 (60.50340788536717)
# condition calc time (ms): 5.86081 (35.723939486419326)
# condition calc time (ms): 0.30684 (1.8703404978855125)
# condition calc time (ms): 0.21029 (1.281771809739722)
# condition calc time (ms): 0.10180 (0.620540320588278)
# AGW
# 175057
# condition calc time (ms): 9.44591 (62.621903994183384)
# condition calc time (ms): 5.02300 (33.30014067365293)
# condition calc time (ms): 0.30518 (2.0231716376626045)
# condition calc time (ms): 0.20504 (1.3593184440545625)
# condition calc time (ms): 0.10490 (0.6954652504465203)
# AGX
# 175057
# condition calc time (ms): 9.27901 (68.75419566830371)
# condition calc time (ms): 3.55816 (26.36469632194467)
# condition calc time (ms): 0.30899 (2.289509945942126)
# condition calc time (ms): 0.23389 (1.7330318340811928)
# condition calc time (ms): 0.11587 (0.8585662297282973)
# AGY
# 175057
# condition calc time (ms): 8.49199 (60.792981617709806)
# condition calc time (ms): 4.64487 (33.25197562682415)
# condition calc time (ms): 0.47517 (3.401662428100838)
# condition calc time (ms): 0.23866 (1.7085118366928946)
# condition calc time (ms): 0.11802 (0.8448684906723105)
# AGZ
# 175057
# condition calc time (ms): 8.59094 (74.91112450884597)
# condition calc time (ms): 2.30384 (20.0889794390969)
# condition calc time (ms): 0.27823 (2.426144986590715)
# condition calc time (ms): 0.18978 (1.6548512504937527)
# ...
# condition calc time (ms): 2.08521 (23.82586902037703)
# condition calc time (ms): 0.27394 (3.130107878391631)
# condition calc time (ms): 0.18287 (2.0894627874032907)
# condition calc time (ms): 0.10204 (1.1659583741963604)
# DLR
# 116663
# condition calc time (ms): 6.99115 (48.34789777411377)
# condition calc time (ms): 6.80304 (47.046990931574605)
# condition calc time (ms): 0.32306 (2.2341302555647156)
# condition calc time (ms): 0.23985 (1.6586974443528442)
# condition calc time (ms): 0.10300 (0.7122835943940643)
# DLS
# 116663
# condition calc time (ms): 6.82402 (53.150359324803624)
# condition calc time (ms): 5.42116 (42.22391413344228)
# condition calc time (ms): 0.28992 (2.2580824868618965)
# condition calc time (ms): 0.20003 (1.5580026369055358)
# condition calc time (ms): 0.10395 (0.8096414179866669)
# DLT
# 116663
# condition calc time (ms): 7.07197 (49.04998925140145)
# condition calc time (ms): 6.27518 (43.52355596712582)
# condition calc time (ms): 0.39601 (2.746680336679179)
# condition calc time (ms): 0.56601 (3.925718915879814)
# condition calc time (ms): 0.10872 (0.7540555289137301)
# DLU
# 116663
# condition calc time (ms): 6.92487 (42.57861174228542)
# condition calc time (ms): 8.57496 (52.724474089276555)
# condition calc time (ms): 0.40722 (2.503848127244741)
# condition calc time (ms): 0.24295 (1.4938063475775123)
# condition calc time (ms): 0.11373 (0.6992596936157737)
# DLV
# 116663
# condition calc time (ms): 7.10702 (61.485942946721394)
# condition calc time (ms): 3.78704 (32.76335059095316)
# condition calc time (ms): 0.32783 (2.836162620407995)
# condition calc time (ms): 0.23293 (2.015222458282626)
# condition calc time (ms): 0.10395 (0.899321383634826)
# DLW
# 116663
# condition calc time (ms): 7.33113 (62.69037085363616)
# condition calc time (ms): 3.71981 (31.8090073192114)
# condition calc time (ms): 0.33998 (2.907296784847805)
# condition calc time (ms): 0.19717 (1.6860690330078085)
# condition calc time (ms): 0.10610 (0.9072560092968256)
# DLX
# 116663
# condition calc time (ms): 6.57225 (63.16247737323282)
# condition calc time (ms): 3.25489 (31.28107600302454)
# condition calc time (ms): 0.29016 (2.7885342437504295)
# condition calc time (ms): 0.18263 (1.7551497376440666)
# condition calc time (ms): 0.10538 (1.0127626423481428)
# DLY
# 116663
# condition calc time (ms): 6.09803 (67.32206780374815)
# condition calc time (ms): 2.35701 (26.02126763529164)
# condition calc time (ms): 0.28396 (3.134870499052432)
# condition calc time (ms): 0.20003 (2.20835965466414)
# condition calc time (ms): 0.11897 (1.3134344072436301)
# DLZ
# 116663
# condition calc time (ms): 5.81098 (75.65260576714157)
# condition calc time (ms): 1.26410 (16.457149951888756)
# condition calc time (ms): 0.26393 (3.4360741223577613)
# condition calc time (ms): 0.21696 (2.824595710339262)
# condition calc time (ms): 0.12517 (1.629574448272651)
# DM?
# 48621
# condition calc time (ms): 3.34215 (25.473841065619947)
# condition calc time (ms): 9.10282 (69.3815987933635)
# condition calc time (ms): 0.37599 (2.865761689291101)
# condition calc time (ms): 0.18406 (1.4028966544912682)
# condition calc time (ms): 0.11492 (0.8759017972341856)
# DMM
# 48621
# condition calc time (ms): 2.59995 (60.98993288590604)
# condition calc time (ms): 1.01304 (23.763982102908276)
# condition calc time (ms): 0.36502 (8.562639821029082)
# condition calc time (ms): 0.17881 (4.194630872483222)
# condition calc time (ms): 0.10610 (2.488814317673378)
# DMN
# 48621
# condition calc time (ms): 3.10421 (43.48842646714987)
# condition calc time (ms): 3.43180 (48.07775810815325)
# condition calc time (ms): 0.29492 (4.131734526871305)
# condition calc time (ms): 0.20099 (2.815725308126524)
# condition calc time (ms): 0.10610 (1.4863555896990548)
# DMO
# 48621
# condition calc time (ms): 3.01504 (43.257850448108364)
# condition calc time (ms): 3.28588 (47.14373674488609)
# condition calc time (ms): 0.32997 (4.73421358691934)
# condition calc time (ms): 0.23723 (3.403571184237532)
# condition calc time (ms): 0.10180 (1.4606280358486694)
# DMP
# 48621
# condition calc time (ms): 3.00503 (57.54462858969091)
# condition calc time (ms): 1.60003 (30.63963840569785)
# condition calc time (ms): 0.32806 (6.282244441400722)
# condition calc time (ms): 0.18406 (3.524631329041684)
# condition calc time (ms): 0.10490 (2.0088572341688353)
# DMQ
# 48621
# condition calc time (ms): 3.13187 (64.69661150512215)
# condition calc time (ms): 1.13988 (23.547084318360913)
# condition calc time (ms): 0.28229 (5.831363278171789)
# condition calc time (ms): 0.18191 (3.757880220646178)
# condition calc time (ms): 0.10490 (2.1670606776989754)
# DMR
# 48621
# condition calc time (ms): 3.02219 (37.93278870036209)
# condition calc time (ms): 4.34995 (54.59795912260227)
# condition calc time (ms): 0.29111 (3.6538288894873867)
# condition calc time (ms): 0.19789 (2.4837657479725888)
# condition calc time (ms): 0.10610 (1.3316575395756651)
# DMS
# 48621
# condition calc time (ms): 3.02410 (51.79045363602956)
# condition calc time (ms): 2.16699 (37.11159201339267)
# condition calc time (ms): 0.35381 (6.059368747703238)
# condition calc time (ms): 0.18930 (3.2420072679759913)
# condition calc time (ms): 0.10490 (1.7965783348985342)
# DMT
# 48621
# condition calc time (ms): 3.13401 (42.74518730489074)
# condition calc time (ms): 3.55601 (48.500910509885536)
# condition calc time (ms): 0.34475 (4.70213319458897)
# condition calc time (ms): 0.19526 (2.6632414151925077)
# condition calc time (ms): 0.10180 (1.3885275754422477)
# DMU
# 48621
# condition calc time (ms): 2.94709 (34.95955653600317)
# condition calc time (ms): 4.51088 (53.50981390350133)
# condition calc time (ms): 0.62799 (7.449516375360598)
# condition calc time (ms): 0.22721 (2.6952881950336556)
# condition calc time (ms): 0.11683 (1.38582499010125)
# DMV
# 48621
# condition calc time (ms): 3.33381 (60.07217424925893)
# condition calc time (ms): 1.60885 (28.98999011900159)
# condition calc time (ms): 0.30422 (5.481806074665979)
# condition calc time (ms): 0.20003 (3.604416376680844)
# condition calc time (ms): 0.10276 (1.8516131803926623)
# DMW
# 48621
# condition calc time (ms): 2.84195 (55.73479216346379)
# condition calc time (ms): 1.62911 (31.94931500444195)
# condition calc time (ms): 0.33784 (6.625520175807734)
# condition calc time (ms): 0.18406 (3.609669425351849)
# condition calc time (ms): 0.10610 (2.08070323093468)
# DMX
# 48621
# condition calc time (ms): 3.12591 (63.35346702101957)
# condition calc time (ms): 1.12200 (22.739792220343077)
# condition calc time (ms): 0.31805 (6.446001449625514)
# condition calc time (ms): 0.21696 (4.397197390674076)
# condition calc time (ms): 0.15116 (3.0635419183377626)
# DMY
# 48621
# condition calc time (ms): 2.91395 (62.05005838452556)
# condition calc time (ms): 1.24097 (26.42534396100929)
# condition calc time (ms): 0.26107 (5.5592222165812055)
# condition calc time (ms): 0.17571 (3.7416865512514597)
# condition calc time (ms): 0.10443 (2.223688886632482)
# DMZ
# 48621
# condition calc time (ms): 2.68006 (68.45502709944583)
# condition calc time (ms): 0.73099 (18.671213689787468)
# condition calc time (ms): 0.23508 (6.004506424700079)
# condition calc time (ms): 0.16785 (4.2871932281834235)
# condition calc time (ms): 0.10109 (2.5820595578831984)
# DN?
# 161791
# condition calc time (ms): 10.98990 (27.764225438644043)
# condition calc time (ms): 27.76909 (70.15413527041434)
# condition calc time (ms): 0.36716 (0.9275823229311602)
# condition calc time (ms): 0.34690 (0.8763845973148299)
# condition calc time (ms): 0.10991 (0.2776723706956265)
# DNN
# 161791
# condition calc time (ms): 7.38263 (42.29324591955201)
# condition calc time (ms): 9.14121 (52.36768421771495)
# condition calc time (ms): 0.46897 (2.6866079355323365)
# condition calc time (ms): 0.32020 (1.8343235675749505)
# condition calc time (ms): 0.14281 (0.8181383596257598)
# DNO
# 161791
# condition calc time (ms): 10.12111 (43.90332188805692)
# condition calc time (ms): 11.92188 (51.71472303810036)
# condition calc time (ms): 0.46396 (2.012576014561701)
# condition calc time (ms): 0.37408 (1.6226781946800148)
# condition calc time (ms): 0.17214 (0.7467008646010012)
# DNP
# 161791
# condition calc time (ms): 9.31382 (61.97645640309684)
# condition calc time (ms): 4.98199 (33.151415154207385)
# condition calc time (ms): 0.36502 (2.4289249904810255)
# condition calc time (ms): 0.23103 (1.5373143799974616)
# condition calc time (ms): 0.13614 (0.9058890722172864)
# DNQ
# 161791
# condition calc time (ms): 9.49383 (59.701940088158565)
# condition calc time (ms): 5.68318 (35.73870280967945)
# condition calc time (ms): 0.36407 (2.289423970733755)
# condition calc time (ms): 0.24581 (1.5457734864613633)
# condition calc time (ms): 0.11516 (0.7241596449668656)
# DNR
# 161791
# condition calc time (ms): 9.60588 (51.77531901769536)
# condition calc time (ms): 8.26502 (44.54810645488775)
# condition calc time (ms): 0.32210 (1.7361244972178316)
# condition calc time (ms): 0.25606 (1.3801611473071438)
# condition calc time (ms): 0.10395 (0.560288882891913)
# DNS
# 161791
# condition calc time (ms): 11.34491 (64.57671742257688)
# condition calc time (ms): 5.50604 (31.341096001954238)
# condition calc time (ms): 0.39005 (2.220231794370708)
# condition calc time (ms): 0.22006 (1.2526124365551123)
# condition calc time (ms): 0.10705 (0.6093423445430611)
# DNT
# 161791
# condition calc time (ms): 9.83810 (44.72868385110673)
# condition calc time (ms): 11.42788 (51.95655472933423)
# condition calc time (ms): 0.35715 (1.6237778307715656)
# condition calc time (ms): 0.26584 (1.2086196804474603)
# condition calc time (ms): 0.10610 (0.4823639083400178)
# DNU
# 161791
# condition calc time (ms): 9.18388 (50.818612382749116)
# condition calc time (ms): 7.78532 (43.07972400691302)
# condition calc time (ms): 0.34881 (1.9301046187944433)
# condition calc time (ms): 0.57912 (3.2045277642185255)
# condition calc time (ms): 0.17476 (0.9670312273248988)
# DNV
# 161791
# condition calc time (ms): 9.28593 (61.54575478406523)
# condition calc time (ms): 5.02300 (33.29172131536116)
# condition calc time (ms): 0.40483 (2.6831850575984073)
# condition calc time (ms): 0.26441 (1.7524453644738713)
# condition calc time (ms): 0.10967 (0.7268934785013352)
# DNW
# 161791
# condition calc time (ms): 9.56297 (68.44476297737279)
# condition calc time (ms): 3.79610 (27.169721169925943)
# condition calc time (ms): 0.30088 (2.153510119108563)
# condition calc time (ms): 0.20790 (1.4880038223951402)
# condition calc time (ms): 0.10395 (0.7440019111975701)
# DNX
# 161791
# condition calc time (ms): 8.16321 (71.11346501339648)
# condition calc time (ms): 2.61402 (22.77192763827445)
# condition calc time (ms): 0.35405 (3.0843043180260454)
# condition calc time (ms): 0.22674 (1.9752009470995078)
# condition calc time (ms): 0.12112 (1.0551020832035225)
# DNY
# 161791
# condition calc time (ms): 8.45695 (67.56895763486742)
# condition calc time (ms): 3.45182 (27.579244132886316)
# condition calc time (ms): 0.29206 (2.3335111246571167)
# condition calc time (ms): 0.20599 (1.6458396830234685)
# condition calc time (ms): 0.10920 (0.8724474245656811)
# DNZ
# 161791
# condition calc time (ms): 8.30698 (69.42711965726811)
# condition calc time (ms): 2.92778 (24.46946298694829)
# condition calc time (ms): 0.41533 (3.4711567201354985)
# condition calc time (ms): 0.20099 (1.6797847962538608)
# condition calc time (ms): 0.11396 (0.9524758393942413)
# DO?
# 187181
# condition calc time (ms): 13.15618 (28.286779066727497)
# condition calc time (ms): 32.37772 (69.61456245482553)
# condition calc time (ms): 0.53191 (1.1436509685918894)
# condition calc time (ms): 0.25439 (0.5469635067178601)
# condition calc time (ms): 0.18978 (0.4080440031372227)
# DOO
# 187181
# condition calc time (ms): 9.93586 (44.27751806204845)
# condition calc time (ms): 11.73019 (52.27369315767106)
# condition calc time (ms): 0.39673 (1.7679558011049723)
# condition calc time (ms): 0.26822 (1.1952826179345517)
# condition calc time (ms): 0.10896 (0.48555036124096895)
# DOP
# 187181
# condition calc time (ms): 10.27417 (63.40842542046173)
# condition calc time (ms): 5.23686 (32.320007062874296)
# condition calc time (ms): 0.33498 (2.0673621635938257)
# condition calc time (ms): 0.23508 (1.4508320948779447)
# condition calc time (ms): 0.12207 (0.7533732581921985)
# DOQ
# 187181
# condition calc time (ms): 9.79304 (71.59041394335512)
# condition calc time (ms): 3.26920 (23.898910675381263)
# condition calc time (ms): 0.30899 (2.2588235294117647)
# condition calc time (ms): 0.20194 (1.4762527233115468)
# condition calc time (ms): 0.10610 (0.775599128540305)
# DOR
# 187181
# condition calc time (ms): 10.76198 (49.016179824085135)
# condition calc time (ms): 10.43391 (47.52198935823651)
# condition calc time (ms): 0.37909 (1.7265718319035726)
# condition calc time (ms): 0.27394 (1.247692474752959)
# condition calc time (ms): 0.10705 (0.48756651102182647)
# DOS
# 187181
# condition calc time (ms): 10.80799 (62.340305568161504)
# condition calc time (ms): 5.85508 (33.77202029786707)
# condition calc time (ms): 0.34189 (1.9720285490325509)
# condition calc time (ms): 0.22817 (1.3160608936012212)
# condition calc time (ms): 0.10395 (0.5995846913376515)
# DOT
# 187181
# condition calc time (ms): 10.05697 (44.56111809509724)
# condition calc time (ms): 11.71589 (51.91155808622347)
# condition calc time (ms): 0.41103 (1.8212357781979907)
# condition calc time (ms): 0.27895 (1.235989478243416)
# condition calc time (ms): 0.10610 (0.47009856223788044)
# DOU
# 187181
# condition calc time (ms): 10.50687 (48.53948672761317)
# condition calc time (ms): 10.37121 (47.91276572309726)
# condition calc time (ms): 0.40293 (1.861438484414583)
# condition calc time (ms): 0.26083 (1.2049785218636413)
# condition calc time (ms): 0.10419 (0.48133054301134487)
# DOV
# 187181
# condition calc time (ms): 10.58507 (57.3523142705817)
# condition calc time (ms): 7.13801 (38.67538205164641)
# condition calc time (ms): 0.39005 (2.113394737182054)
# condition calc time (ms): 0.23079 (1.2504682797018511)
# condition calc time (ms): 0.11230 (0.6084406608879875)
# DOW
# 187181
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8b09599e54ae> in <module>()
#      11         df_dict[leave] = df_dict[leave[:-1]].loc[condition]
#      12         t4 = time.time()
# ---> 13         ev_df.loc[leave]['mean'] = df_dict[leave]['score'].mean()
#      14         t5 = time.time()
#      15         ev_df.loc[leave]['std'] = df_dict[leave]['score'].std()
#
# /Users/Siwen/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /Users/Siwen/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1481         # fall thru to straight lookup
#    1482         self._has_valid_type(key, axis)
# -> 1483         return self._get_label(key, axis=axis)
#    1484
#    1485
#
# /Users/Siwen/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     100             raise IndexingError('no slices here, handle elsewhere')
#     101
# --> 102         return self.obj._xs(label, axis=axis)
#     103
#     104     def _get_loc(self, key, axis=0):
#
# /Users/Siwen/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    1802             result = self._constructor_sliced(
#    1803                 new_values, index=self.columns,
# -> 1804                 name=self.index[loc], dtype=new_values.dtype)
#    1805
#    1806         else:
#
# /Users/Siwen/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     243                                        raise_cast_failure=True)
#     244
# --> 245                 data = SingleBlockManager(data, index, fastpath=True)
#     246
#     247         generic.NDFrame.__init__(self, data, fastpath=True)
#
# /Users/Siwen/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4039         # passed from constructor, single block, single axis
#    4040         if fastpath:
# -> 4041             self.axes = [axis]
#    4042             if isinstance(block, list):
#    4043
#
# KeyboardInterrupt:

# %% [markdown]
# #### Benchmark figures
# With 2M racks, following amount of time was taken:
# * 1 - 3s (.11s/leave)
# * 2 - 15s (.04s/leave)
# * 3 - 38s (.011s/leave)
# * 4 - 84s (.0033s/leave)
# * 5 - 244s (.0016s/leave)
#
# -> 383s total
#
# Using improvement of non-alphabetical leaves, performance was as follows:
# * 1 - 3s (.11s/leave)
# * 2 - 10s (.027s/leave)
# * 3 - 23s (.0066s/leave)
# * 4 - 64s (.0025s/leave)
# * 5 - 226s (.0015s/leave)
#
# -> 326 total (15% faster than previous version)

# %%
for leave_length in range(1,ev_calculator_max_length+1):
    print(leave_length)
    t0 = time.time()
    
    for leave in leaves[leave_length]:
        condition = df_dict[leave[:-1]][get_columns(leave)].all(axis=1)
        df_dict[leave] = df_dict[leave[:-1]].loc[condition]
        ev_df.loc[leave]['mean'] = df_dict[leave]['score'].mean()
        ev_df.loc[leave]['std'] = df_dict[leave]['score'].std()
        ev_df.loc[leave]['count'] = len(df_dict[leave])
        
    t1 = time.time()
    print('Calculated mean, std and count in {} seconds'.format(t1-t0))
# Out:
# 1
# Calculated mean, std and count in 2.7654788494110107 seconds
# 2
# Calculated mean, std and count in 9.538146018981934 seconds
# 3
# Calculated mean, std and count in 23.050843000411987 seconds
# 4
# Calculated mean, std and count in 63.77771186828613 seconds
# 5
# Calculated mean, std and count in 225.8342740535736 seconds

# %%
ev_df['pct'] = 100*ev_df['count']/len(df)
ev_df['ev'] = ev_df['mean']-df['score'].mean()

# %% [markdown]
# Calculate leave "synergy", in other words the difference between the EV of the rack and what we'd expect just from adding the individual values of the tiles

# %%
for leave_length in range(2,ev_calculator_max_length+1):
    for leave in leaves[leave_length]:
        ev_df.loc[leave]['synergy'] = ev_df.loc[leave]['ev']-\
                                      sum([ev_df.loc[c]['ev'] for c in leave])

# %%
ev_df

# %%
ev_df.to_csv('leave_values_011219_v7.csv')

# %%
ev_df.sort_values('synergy')

# %% [markdown]
# ### Scratch
#
# -consult time is just the length of the dataframe
# -the dictionary-making time is actually slightly slower for longer dataframes also.
#
#
# AAI 10 13 23
# ABI  6  7 13
# ACI  7  7 13
# ADI 11 11 22
# AEI 26 44 70
# AFI  6  7 13
# AGI 11 15 26
# AHI  5  6 11
# AII 21 23 44
# AIJ 21  6 27
# AIK 21  6 27
# AIL 24 17 41
# AIM 21  9 30
# AIN 23 23 46
# AIO 24 32 56
# AIP 23 13 35
# AIQ 24  7 31
# AIR 26 21 47
# AIS 23 19 42
# AIT 24 25 49
# AIU 24 23 47
# AIV 23 10 33
# AIW 22  9 31
# AIX 21  7 28
# AIY 21  7 29
# AIZ 22  6 27
# AI? 23  8 31
#
# ABI/ACI/AFI/AHI - 13/13/13/11
# dictionary-making - 7/7/7/6
# AIM/AIP/AIV/AIW/AIY - 30/35/33/31/29
# dictionary-making - 9/13/10/9/7
#
#
# strategies
# -Order racks with least common letters first
# -Skip recalculating if that dictionary's already in
# -Still need to figure out memory issues
#
#
# letter rarity:
# ZXKJQ?HYMFPWBCVSGDLURTNAOIE
